# %% [markdown]
# # Feature Creation
# ### Author: Terence Kaplan

# %%
# Load necessary packages
import pandas as pd
import numpy as np

# %%
# Read the CSV file into a data frame
df = pd.read_csv('./HI-Small_Trans.csv')

# %%
# Convert variable "Timestamp" to date and time and arrange in ascending order
df['Timestamp'] = pd.to_datetime(df['Timestamp'], format='%Y/%m/%d %H:%M')
df = df.sort_values('Timestamp')

# %%
# Rename variables "Account" to "From Account" and "Account.1" to "To Account"
df = df.rename(columns={"Account": "From Account", "Account.1": "To Account"})

# %% [markdown]
# ### Descriptive Statistics

# %%
# Inspect the data set
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5078345 entries, 316720 to 4962234
# Data columns (total 11 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Timestamp           datetime64[ns]
#  1   From Bank           int64
#  2   From Account        object
#  3   To Bank             int64
#  4   To Account          object
#  5   Amount Received     float64
#  6   Receiving Currency  object
#  7   Amount Paid         float64
#  8   Payment Currency    object
#  9   Payment Format      object
#  10  Is Laundering       int64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(5)
# memory usage: 464.9+ MB

# %%
# Get length of timespan
df['Timestamp'].min(), df['Timestamp'].max()
# Out:
# (Timestamp('2022-09-01 00:00:00'), Timestamp('2022-09-18 16:18:00'))

# %%
# Number and ratio of non-fraud and fraud cases
occ = df['Is Laundering'].value_counts()
occ, occ / len(df.index)
# Out:
# (0    5073168
#  1       5177
#  Name: Is Laundering, dtype: int64,
#  0    0.998981
#  1    0.001019
#  Name: Is Laundering, dtype: float64)

# %%
# Count number of unique accounts
all_accounts = pd.concat([df['From Account'], df['To Account']])
all_accounts.nunique()
# Out:
# 515080

# %%
# Count number of unique banks
all_banks = pd.concat([df['From Bank'], df['To Bank']])
all_banks.nunique()
# Out:
# 30470

# %%
# Calculate number of transactions for each currency

# For all observations
currency_counts = df['Payment Currency'].value_counts().sort_values(ascending=False)
currency_percentage = ((currency_counts / len(df)) * 100).round(1)

# For observations grouped by class

# Calculate number of transactions
currency_grouped_counts = df.groupby(['Is Laundering', 'Payment Currency']).size()

# Calculate total number of transactions for each class
currency_total_counts = df.groupby('Is Laundering').size()

# Calculate percentages for each class
currency_grouped_percentage = (currency_grouped_counts / currency_total_counts * 100).round(1)

# Merge all into one data frame
currency_counts_all = pd.DataFrame({
    'Currency': currency_counts.index,
    'Counts total': currency_counts.values,
    'Percentage total': currency_percentage.values,
    'Counts legitimate': currency_grouped_counts[0].reindex(currency_counts.index, fill_value=0).values,
    'Percentage legitimate': currency_grouped_percentage[0].reindex(currency_counts.index, fill_value=0).values,
    'Counts fraudulent': currency_grouped_counts[1].reindex(currency_counts.index, fill_value=0).values,
    'Percentage fraudulent': currency_grouped_percentage[1].reindex(currency_counts.index, fill_value=0).values
}).set_index('Currency')

currency_counts_all
# Out:
#                    Counts total  Percentage total  Counts legitimate  \
# Currency
# US Dollar               1895172              37.3            1893260
# Euro                    1168297              23.0            1166925
# Swiss Franc              234860               4.6             234667
# Yuan                     213752               4.2             213568
# Shekel                   192184               3.8             192089
# Rupee                    190202               3.7             190035
# UK Pound                 180738               3.6             180606
# Yen                      155209               3.1             155054
# Ruble                    155178               3.1             155045
# Bitcoin                  146066               2.9             146010
# Canadian Dollar          140042               2.8             139914
# Australian Dollar        136769               2.7             136642
# Mexican Peso             110159               2.2             110067
# Saudi Riyal               89014               1.8              88640
# Brazil Real               70703               1.4              70646
#
#                    Percentage legitimate  Counts fraudulent  \
# Currency
# US Dollar                           37.3               1912
# Euro                                23.0               1372
# Swiss Franc                          4.6                193
# Yuan                                 4.2                184
# Shekel                               3.8                 95
# Rupee                                3.7                167
# UK Pound                             3.6                132
# Yen                                  3.1                155
# Ruble                                3.1                133
# Bitcoin                              2.9                 56
# Canadian Dollar                      2.8                128
# Australian Dollar                    2.7                127
# Mexican Peso                         2.2                 92
# Saudi Riyal                          1.7                374
# Brazil Real                          1.4                 57
#
#                    Percentage fraudulent
# Currency
# US Dollar                           36.9
# Euro                                26.5
# Swiss Franc                          3.7
# Yuan                                 3.6
# Shekel                               1.8
# Rupee                                3.2
# UK Pound                             2.5
# Yen                                  3.0
# Ruble                                2.6
# Bitcoin                              1.1
# Canadian Dollar                      2.5
# Australian Dollar                    2.5
# Mexican Peso                         1.8
# Saudi Riyal                          7.2
# Brazil Real                          1.1

# %%
# Calculate number of transactions for each payment format

# For all observations
format_counts = df['Payment Format'].value_counts().sort_values(ascending=False)
format_percentage = ((format_counts / len(df)) * 100).round(1)

# For observations grouped by class

# Calculate number of transactions
format_grouped_counts = df.groupby(['Is Laundering', 'Payment Format']).size()

# Calculate total number of transactions for each class
format_total_counts = df.groupby('Is Laundering').size()

# Calculate percentages for each class
format_grouped_percentage = (format_grouped_counts / format_total_counts * 100).round(1)

# Merge all into one data frame
format_counts_all = pd.DataFrame({
    'Format': format_counts.index,
    'Counts total': format_counts.values,
    'Percentage total': format_percentage.values,
    'Counts legitimate': format_grouped_counts[0].reindex(format_counts.index, fill_value=0).values,
    'Percentage legitimate': format_grouped_percentage[0].reindex(format_counts.index, fill_value=0).values,
    'Counts fraudulent': format_grouped_counts[1].reindex(format_counts.index, fill_value=0).values,
    'Percentage fraudulent': format_grouped_percentage[1].reindex(format_counts.index, fill_value=0).values
}).set_index('Format')

format_counts_all
# Out:
#               Counts total  Percentage total  Counts legitimate  \
# Format
# Cheque             1864331              36.7            1864007
# Credit Card        1323324              26.1            1323118
# ACH                 600797              11.8             596314
# Cash                490891               9.7             490783
# Reinvestment        481056               9.5             481056
# Wire                171855               3.4             171855
# Bitcoin             146091               2.9             146035
#
#               Percentage legitimate  Counts fraudulent  Percentage fraudulent
# Format
# Cheque                         36.7                324                    6.3
# Credit Card                    26.1                206                    4.0
# ACH                            11.8               4483                   86.6
# Cash                            9.7                108                    2.1
# Reinvestment                    9.5                  0                    0.0
# Wire                            3.4                  0                    0.0
# Bitcoin                         2.9                 56                    1.1

# %% [markdown]
# ### V1: Average of the Digits Sums & Average Number of Zeros

# %%
# Create function to calculate the sum of digits of a transaction amount
def digit_sum(amount):
    return sum(int(digit) for digit in str(amount) if digit.isdigit())

# Create function to count the number of zeros of a transaction amount
def count_zeros(amount):
    formatted_amount = "{:.6f}".format(amount)
    return formatted_amount.count('0')

# Compute the sum of digits and the number of zeros for each transaction
df['Digit Sum Amount Received'] = df['Amount Received'].apply(digit_sum)
df['Digit Sum Amount Paid'] = df['Amount Paid'].apply(digit_sum)
df['Count Zeros Amount Received'] = df['Amount Received'].apply(count_zeros)
df['Count Zeros Amount Paid'] = df['Amount Paid'].apply(count_zeros)

# Calculate the average digit sum and average number of zeros for paid transactions by each account
paid_digit_stats = df.groupby('From Account').agg({
    'Digit Sum Amount Paid': np.mean,
    'Count Zeros Amount Paid': np.mean
}).reset_index()
paid_digit_stats.rename(columns={
    'Digit Sum Amount Paid': 'Average Digit Sum Paid',
    'Count Zeros Amount Paid': 'Average Count Zeros Paid'
}, inplace=True)

# Calculate the average digit sum and average number of zeros for received transactions by each account
received_digit_stats = df.groupby('To Account').agg({
    'Digit Sum Amount Received': np.mean,
    'Count Zeros Amount Received': np.mean
}).reset_index()
received_digit_stats.rename(columns={
    'Digit Sum Amount Received': 'Average Digit Sum Received',
    'Count Zeros Amount Received': 'Average Count Zeros Received'
}, inplace=True)

# Merge both data sets into a single data frame
digit_stats = pd.merge(paid_digit_stats, received_digit_stats, how='outer', left_on='From Account', right_on='To Account')

# Combine the two account IDs in a new variable "Account ID"
digit_stats['Account ID'] = digit_stats['From Account'].combine_first(digit_stats['To Account'])

# Drop redundant columns
digit_stats = digit_stats.drop(columns=['From Account', 'To Account'])
digit_stats.head()
# Out:
#    Average Digit Sum Paid  Average Count Zeros Paid  \
# 0               23.920141                  4.480584
# 1               23.354880                  4.484886
# 2               27.371377                  4.560092
# 3               32.610425                  4.693297
# 4               32.097949                  4.635832
#
#    Average Digit Sum Received  Average Count Zeros Received Account ID
# 0                   20.681734                      4.426199  100428660
# 1                   19.860643                      4.382848  1004286A8
# 2                   24.629630                      4.351852  1004286F0
# 3                   30.081633                      4.581633  100428738
# 4                   29.290598                      4.632479  100428780

# %%
# Merge with variable "From Account"
df_v1 = pd.merge(df, digit_stats, how='left', left_on='From Account', right_on='Account ID')
df_v1.rename(columns={
    'Average Digit Sum Paid': 'From Account Average Digit Sum Paid',
    'Average Count Zeros Paid': 'From Account Average Count Zeros Paid',
    'Average Digit Sum Received': 'From Account Average Digit Sum Received',
    'Average Count Zeros Received': 'From Account Average Count Zeros Received'
}, inplace=True)
df_v1.drop(columns=['Account ID'], inplace=True)

# Merge with variable "To Account"
df_v1 = pd.merge(df_v1, digit_stats, how='left', left_on='To Account', right_on='Account ID')
df_v1.rename(columns={
    'Average Digit Sum Paid': 'To Account Average Digit Sum Paid',
    'Average Count Zeros Paid': 'To Account Average Count Zeros Paid',
    'Average Digit Sum Received': 'To Account Average Digit Sum Received',
    'Average Count Zeros Received': 'To Account Average Count Zeros Received'
}, inplace=True)
df_v1.drop(columns=['Account ID'], inplace=True)
df_v1.head()
# Out:
#    Timestamp  From Bank From Account  To Bank To Account  Amount Received  \
# 0 2022-09-01        121    8123FB9B0      121  8123FB9B0            47.64
# 1 2022-09-01      25170    8095AF7C0    25170  8095AF7C0          3917.42
# 2 2022-09-01      25665    809A7D4B0    24779  809189BA0            97.49
# 3 2022-09-01      32317    800D4E490    12004  800D4E750         13939.05
# 4 2022-09-01       1024    800C8D9D0     1024  800C8D9D0            10.37
#
#   Receiving Currency  Amount Paid Payment Currency Payment Format  ...  \
# 0        Saudi Riyal        47.64      Saudi Riyal   Reinvestment  ...
# 1    Canadian Dollar      3917.42  Canadian Dollar   Reinvestment  ...
# 2    Canadian Dollar        97.49  Canadian Dollar    Credit Card  ...
# 3               Euro     13939.05             Euro           Wire  ...
# 4               Euro        10.37             Euro   Reinvestment  ...
#
#    Count Zeros Amount Received  Count Zeros Amount Paid  \
# 0                            4                        4
# 1                            4                        4
# 2                            4                        4
# 3                            5                        5
# 4                            5                        5
#
#    From Account Average Digit Sum Paid  From Account Average Count Zeros Paid  \
# 0                            24.000000                               4.333333
# 1                            19.666667                               4.666667
# 2                            17.700000                               4.700000
# 3                            30.000000                               5.000000
# 4                            19.333333                               4.766667
#
#    From Account Average Digit Sum Received  \
# 0                                26.071429
# 1                                18.500000
# 2                                22.000000
# 3                                      NaN
# 4                                19.250000
#
#    From Account Average Count Zeros Received  \
# 0                                   4.857143
# 1                                   4.000000
# 2                                   6.000000
# 3                                        NaN
# 4                                   4.500000
#
#    To Account Average Digit Sum Paid  To Account Average Count Zeros Paid  \
# 0                          24.000000                             4.333333
# 1                          19.666667                             4.666667
# 2                          27.017544                             4.438596
# 3                          26.000000                             4.888889
# 4                          19.333333                             4.766667
#
#    To Account Average Digit Sum Received  \
# 0                              26.071429
# 1                              18.500000
# 2                              18.463415
# 3                              25.500000
# 4                              19.250000
#
#    To Account Average Count Zeros Received
# 0                                 4.857143
# 1                                 4.000000
# 2                                 4.658537
# 3                                 4.500000
# 4                                 4.500000
#
# [5 rows x 23 columns]

# %%
# CHECK RESULTS - Average of the digit sums and average number of zeros by a selected account

# Check whether digit sums and number are correct calculated for a specific account
df_v1_test = df[df['From Account'] == '100428780']
df_v1_test.describe() # to find average

df_v1_test2 = df[df['To Account'] == '100428780']
df_v1_test2.describe() # to find average

# Check with the corresponding variables
df_v1_test2 = df_v1[df_v1['To Account'] == '100428780']
df_v1_test2.head()
# Out:
#                  Timestamp  From Bank From Account  To Bank To Account  \
# 114023 2022-09-01 00:10:00     313638    804F4AED0       70  100428780
# 124189 2022-09-01 00:11:00     312747    8054CB880       70  100428780
# 139045 2022-09-01 00:12:00     312246    805410180       70  100428780
# 465982 2022-09-01 04:38:00     312830    80536CA40       70  100428780
# 724918 2022-09-01 12:22:00     313167    804CDF110       70  100428780
#
#         Amount Received Receiving Currency  Amount Paid Payment Currency  \
# 114023             0.11              Rupee         0.11            Rupee
# 124189             0.10              Rupee         0.10            Rupee
# 139045             0.03              Rupee         0.03            Rupee
# 465982             0.08              Rupee         0.08            Rupee
# 724918             0.47              Rupee         0.47            Rupee
#
#        Payment Format  ...  Count Zeros Amount Received  \
# 114023           Cash  ...                            5
# 124189           Cash  ...                            6
# 139045           Cash  ...                            6
# 465982           Cash  ...                            6
# 724918           Cash  ...                            5
#
#         Count Zeros Amount Paid  From Account Average Digit Sum Paid  \
# 114023                        5                            16.666667
# 124189                        6                            19.000000
# 139045                        6                            23.666667
# 465982                        6                            22.666667
# 724918                        5                            14.333333
#
#         From Account Average Count Zeros Paid  \
# 114023                               5.666667
# 124189                               4.666667
# 139045                               4.666667
# 465982                               4.666667
# 724918                               5.666667
#
#         From Account Average Digit Sum Received  \
# 114023                                      NaN
# 124189                                      NaN
# 139045                                      NaN
# 465982                                      NaN
# 724918                                      NaN
#
#         From Account Average Count Zeros Received  \
# 114023                                        NaN
# 124189                                        NaN
# 139045                                        NaN
# 465982                                        NaN
# 724918                                        NaN
#
#         To Account Average Digit Sum Paid  \
# 114023                          32.097949
# 124189                          32.097949
# 139045                          32.097949
# 465982                          32.097949
# 724918                          32.097949
#
#         To Account Average Count Zeros Paid  \
# 114023                             4.635832
# 124189                             4.635832
# 139045                             4.635832
# 465982                             4.635832
# 724918                             4.635832
#
#         To Account Average Digit Sum Received  \
# 114023                              29.290598
# 124189                              29.290598
# 139045                              29.290598
# 465982                              29.290598
# 724918                              29.290598
#
#         To Account Average Count Zeros Received
# 114023                                 4.632479
# 124189                                 4.632479
# 139045                                 4.632479
# 465982                                 4.632479
# 724918                                 4.632479
#
# [5 rows x 23 columns]

# %% [markdown]
# ### V2: Average Ratio of Zeros compared to Total Number of Digits

# %%
# Create function to calculate the ratio of zero digits to the total number of a transaction amount
def zero_digit_ratio(amount):
    amount_str = "{:.6f}".format(amount)
    return amount_str.count('0') / (len(amount_str) - int("." in amount_str))

# Compute the ratio of zero digits for each transaction
df['Zero Digit Ratio Amount Received'] = df['Amount Received'].apply(zero_digit_ratio)
df['Zero Digit Ratio Amount Paid'] = df['Amount Paid'].apply(zero_digit_ratio)

# Calculate the average zero digit ratio for paid transactions by each account
paid_zero_digit_ratio_stats = df.groupby('From Account')['Zero Digit Ratio Amount Paid'].mean().reset_index()
paid_zero_digit_ratio_stats.rename(columns={
    'Zero Digit Ratio Amount Paid': 'Average Zero Digit Ratio Paid'
}, inplace=True)

# Calculate the average zero digit ratio for received transactions by each account
received_zero_digit_ratio_stats = df.groupby('To Account')['Zero Digit Ratio Amount Received'].mean().reset_index()
received_zero_digit_ratio_stats.rename(columns={
    'Zero Digit Ratio Amount Received': 'Average Zero Digit Ratio Received'
}, inplace=True)

# Merge both data sets into a single data frame
zero_digit_ratio_stats = pd.merge(paid_zero_digit_ratio_stats, received_zero_digit_ratio_stats, how='outer', left_on='From Account', right_on='To Account')

# Combine the two account IDs in a new variable "Account ID"
zero_digit_ratio_stats['Account ID'] = zero_digit_ratio_stats['From Account'].combine_first(zero_digit_ratio_stats['To Account'])

# Drop redundant columns
zero_digit_ratio_stats = zero_digit_ratio_stats.drop(columns=['From Account', 'To Account'])
zero_digit_ratio_stats.head()
# Out:
#    Average Zero Digit Ratio Paid  Average Zero Digit Ratio Received Account ID
# 0                       0.470215                           0.498400  100428660
# 1                       0.475983                           0.498757  1004286A8
# 2                       0.443252                           0.458391  1004286F0
# 3                       0.407221                           0.439213  100428738
# 4                       0.408176                           0.435559  100428780

# %%
# Merge with variable "From Account"
df_v2 = pd.merge(df_v1, zero_digit_ratio_stats, how='left', left_on='From Account', right_on='Account ID')
df_v2.rename(columns={
    'Average Zero Digit Ratio Paid': 'From Account Average Zero Digit Ratio Paid',
    'Average Zero Digit Ratio Received': 'From Account Average Zero Digit Ratio Received'
}, inplace=True)
df_v2.drop(columns=['Account ID'], inplace=True)

# Merge with variable "To Account"
df_v2 = pd.merge(df_v2, zero_digit_ratio_stats, how='left', left_on='To Account', right_on='Account ID')
df_v2.rename(columns={
    'Average Zero Digit Ratio Paid': 'To Account Average Zero Digit Ratio Paid',
    'Average Zero Digit Ratio Received': 'To Account Average Zero Digit Ratio Received'
}, inplace=True)
df_v2.drop(columns=['Account ID'], inplace=True)
df_v2.head()
# Out:
#    Timestamp  From Bank From Account  To Bank To Account  Amount Received  \
# 0 2022-09-01        121    8123FB9B0      121  8123FB9B0            47.64
# 1 2022-09-01      25170    8095AF7C0    25170  8095AF7C0          3917.42
# 2 2022-09-01      25665    809A7D4B0    24779  809189BA0            97.49
# 3 2022-09-01      32317    800D4E490    12004  800D4E750         13939.05
# 4 2022-09-01       1024    800C8D9D0     1024  800C8D9D0            10.37
#
#   Receiving Currency  Amount Paid Payment Currency Payment Format  ...  \
# 0        Saudi Riyal        47.64      Saudi Riyal   Reinvestment  ...
# 1    Canadian Dollar      3917.42  Canadian Dollar   Reinvestment  ...
# 2    Canadian Dollar        97.49  Canadian Dollar    Credit Card  ...
# 3               Euro     13939.05             Euro           Wire  ...
# 4               Euro        10.37             Euro   Reinvestment  ...
#
#    From Account Average Digit Sum Received  \
# 0                                26.071429
# 1                                18.500000
# 2                                22.000000
# 3                                      NaN
# 4                                19.250000
#
#    From Account Average Count Zeros Received  \
# 0                                   4.857143
# 1                                   4.000000
# 2                                   6.000000
# 3                                        NaN
# 4                                   4.500000
#
#    To Account Average Digit Sum Paid  To Account Average Count Zeros Paid  \
# 0                          24.000000                             4.333333
# 1                          19.666667                             4.666667
# 2                          27.017544                             4.438596
# 3                          26.000000                             4.888889
# 4                          19.333333                             4.766667
#
#    To Account Average Digit Sum Received  \
# 0                              26.071429
# 1                              18.500000
# 2                              18.463415
# 3                              25.500000
# 4                              19.250000
#
#    To Account Average Count Zeros Received  \
# 0                                 4.857143
# 1                                 4.000000
# 2                                 4.658537
# 3                                 4.500000
# 4                                 4.500000
#
#    From Account Average Zero Digit Ratio Paid  \
# 0                                    0.485185
# 1                                    0.500000
# 2                                    0.582143
# 3                                    0.454545
# 4                                    0.595648
#
#    From Account Average Zero Digit Ratio Received  \
# 0                                        0.488276
# 1                                        0.450000
# 2                                        0.600000
# 3                                             NaN
# 4                                        0.517361
#
#    To Account Average Zero Digit Ratio Paid  \
# 0                                  0.485185
# 1                                  0.500000
# 2                                  0.450642
# 3                                  0.485602
# 4                                  0.595648
#
#    To Account Average Zero Digit Ratio Received
# 0                                      0.488276
# 1                                      0.450000
# 2                                      0.527153
# 3                                      0.458417
# 4                                      0.517361
#
# [5 rows x 27 columns]

# %%
# CHECK RESULTS - Average ratio of zeros compared to total number of digits by a selected account

# Check whether ratio of zeros are correct calculated for a specific account
df_v2_test = df[df['From Account'] == '100428780']
df_v2_test.head(20) # to control if a single transaction is correctly calculated
df_v2_test.describe() # to find average

# Check with the corresponding variables
df_v2_test2 = df_v2[df_v2['From Account'] == '100428780']
df_v2_test2.head()
# Out:
#                 Timestamp  From Bank From Account  To Bank To Account  \
# 8830  2022-09-01 00:00:00         70    100428780   113304  805C41320
# 9125  2022-09-01 00:00:00         70    100428780   113530  8056886E0
# 9577  2022-09-01 00:00:00         70    100428780   212789  8050C39D0
# 9677  2022-09-01 00:00:00         70    100428780    14629  8059211D0
# 12158 2022-09-01 00:01:00         70    100428780   112733  805C2A320
#
#        Amount Received Receiving Currency  Amount Paid Payment Currency  \
# 8830           2304.14              Rupee      2304.14            Rupee
# 9125         740240.35              Rupee    740240.35            Rupee
# 9577        9212380.32              Rupee   9212380.32            Rupee
# 9677         665742.62              Rupee    665742.62            Rupee
# 12158          3095.91              Rupee      3095.91            Rupee
#
#       Payment Format  ...  From Account Average Digit Sum Received  \
# 8830     Credit Card  ...                                29.290598
# 9125          Cheque  ...                                29.290598
# 9577            Cash  ...                                29.290598
# 9677     Credit Card  ...                                29.290598
# 12158         Cheque  ...                                29.290598
#
#        From Account Average Count Zeros Received  \
# 8830                                    4.632479
# 9125                                    4.632479
# 9577                                    4.632479
# 9677                                    4.632479
# 12158                                   4.632479
#
#        To Account Average Digit Sum Paid  To Account Average Count Zeros Paid  \
# 8830                           16.000000                             4.000000
# 9125                           30.566667                             4.733333
# 9577                           39.000000                             4.000000
# 9677                           21.000000                             4.000000
# 12158                          38.000000                             5.000000
#
#        To Account Average Digit Sum Received  \
# 8830                               24.866667
# 9125                               31.333333
# 9577                               33.933333
# 9677                               37.821429
# 12158                              21.333333
#
#        To Account Average Count Zeros Received  \
# 8830                                  4.466667
# 9125                                  4.185185
# 9577                                  4.800000
# 9677                                  4.785714
# 12158                                 5.476190
#
#        From Account Average Zero Digit Ratio Paid  \
# 8830                                     0.408176
# 9125                                     0.408176
# 9577                                     0.408176
# 9677                                     0.408176
# 12158                                    0.408176
#
#        From Account Average Zero Digit Ratio Received  \
# 8830                                         0.435559
# 9125                                         0.435559
# 9577                                         0.435559
# 9677                                         0.435559
# 12158                                        0.435559
#
#        To Account Average Zero Digit Ratio Paid  \
# 8830                                   0.444444
# 9125                                   0.430455
# 9577                                   0.376068
# 9677                                   0.400000
# 12158                                  0.416667
#
#        To Account Average Zero Digit Ratio Received
# 8830                                       0.432660
# 9125                                       0.396886
# 9577                                       0.377225
# 9677                                       0.404426
# 12158                                      0.517677
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Convert all Amounts into US-Dollars (for comparability)

# %%
# Convert all currencies to US-Dollars (exchange rates from 09/2022, waehrungsrechner.org)
currency_multipliers = {
    'Australian Dollar': 0.67926,
    'Bitcoin': 20000,
    'Brazil Real': 0.19256,
    'Canadian Dollar': 0.76011,
    'Euro': 0.99622,
    'Mexican Peso': 0.05031,
    'Ruble': 0.01673,
    'Rupee': 0.01255,
    'Saudi Riyal': 0.26612,
    'Shekel': 0.29351,
    'Swiss Franc': 0.98166,
    'UK Pound': 1.15331,
    'Yen': 0.00713,
    'Yuan': 0.14446
}
for currency, multiplier in currency_multipliers.items():
    df_v2.loc[df_v2['Payment Currency'] == currency, 'Amount Paid'] *= multiplier
    df_v2.loc[df_v2['Receiving Currency'] == currency, 'Amount Received'] *= multiplier
    
df_v2.head()
# Out:
#    Timestamp  From Bank From Account  To Bank To Account  Amount Received  \
# 0 2022-09-01        121    8123FB9B0      121  8123FB9B0        12.677957
# 1 2022-09-01      25170    8095AF7C0    25170  8095AF7C0      2977.670116
# 2 2022-09-01      25665    809A7D4B0    24779  809189BA0        74.103124
# 3 2022-09-01      32317    800D4E490    12004  800D4E750     13886.360391
# 4 2022-09-01       1024    800C8D9D0     1024  800C8D9D0        10.330801
#
#   Receiving Currency   Amount Paid Payment Currency Payment Format  ...  \
# 0        Saudi Riyal     12.677957      Saudi Riyal   Reinvestment  ...
# 1    Canadian Dollar   2977.670116  Canadian Dollar   Reinvestment  ...
# 2    Canadian Dollar     74.103124  Canadian Dollar    Credit Card  ...
# 3               Euro  13886.360391             Euro           Wire  ...
# 4               Euro     10.330801             Euro   Reinvestment  ...
#
#    From Account Average Digit Sum Received  \
# 0                                26.071429
# 1                                18.500000
# 2                                22.000000
# 3                                      NaN
# 4                                19.250000
#
#    From Account Average Count Zeros Received  \
# 0                                   4.857143
# 1                                   4.000000
# 2                                   6.000000
# 3                                        NaN
# 4                                   4.500000
#
#    To Account Average Digit Sum Paid  To Account Average Count Zeros Paid  \
# 0                          24.000000                             4.333333
# 1                          19.666667                             4.666667
# 2                          27.017544                             4.438596
# 3                          26.000000                             4.888889
# 4                          19.333333                             4.766667
#
#    To Account Average Digit Sum Received  \
# 0                              26.071429
# 1                              18.500000
# 2                              18.463415
# 3                              25.500000
# 4                              19.250000
#
#    To Account Average Count Zeros Received  \
# 0                                 4.857143
# 1                                 4.000000
# 2                                 4.658537
# 3                                 4.500000
# 4                                 4.500000
#
#    From Account Average Zero Digit Ratio Paid  \
# 0                                    0.485185
# 1                                    0.500000
# 2                                    0.582143
# 3                                    0.454545
# 4                                    0.595648
#
#    From Account Average Zero Digit Ratio Received  \
# 0                                        0.488276
# 1                                        0.450000
# 2                                        0.600000
# 3                                             NaN
# 4                                        0.517361
#
#    To Account Average Zero Digit Ratio Paid  \
# 0                                  0.485185
# 1                                  0.500000
# 2                                  0.450642
# 3                                  0.485602
# 4                                  0.595648
#
#    To Account Average Zero Digit Ratio Received
# 0                                      0.488276
# 1                                      0.450000
# 2                                      0.527153
# 3                                      0.458417
# 4                                      0.517361
#
# [5 rows x 27 columns]

# %%
# Calculate descriptive statistics of "Amount Paid"
df_v2['Amount Paid'].describe(), df_v2.groupby('Is Laundering')['Amount Paid'].describe()
# Out:
# (count    5.078345e+06
#  mean     3.436240e+05
#  std      2.456332e+07
#  min      7.130000e-05
#  25%      1.521100e+02
#  50%      8.616000e+02
#  75%      5.147710e+03
#  max      2.887692e+10
#  Name: Amount Paid, dtype: float64,
#                     count          mean           std       min      25%  \
#  Is Laundering
#  0              5073168.0  3.387590e+05  2.343559e+07  0.000071   151.90
#  1                 5177.0  5.111051e+06  2.315927e+08  0.328753  2041.64
#
#                         50%           75%           max
#  Is Laundering
#  0               859.239750   5133.103616  2.887692e+10
#  1              5668.880326  12858.473980  1.634289e+10  )

# %% [markdown]
# ### V3: Dynamic Variables: Min, Mean, Median, Max, Sum & Count

# %%
# Create dynamic Min, Mean, Median, Max, Sum & Count for every sender account ("From Account")
df_v3 = df_v2.copy()
df_v3['From Account Amount Paid Min'] = df_v3.groupby('From Account')['Amount Paid'].transform(lambda x: x.expanding().min())
df_v3['From Account Amount Paid Mean'] = df_v3.groupby('From Account')['Amount Paid'].transform(lambda x: x.expanding().mean())
df_v3['From Account Amount Paid Median'] = df_v3.groupby('From Account')['Amount Paid'].transform(lambda x: x.expanding().median())
df_v3['From Account Amount Paid Max'] = df_v3.groupby('From Account')['Amount Paid'].transform(lambda x: x.expanding().max())
df_v3['From Account Amount Paid Sum'] = df_v3.groupby('From Account')['Amount Paid'].transform(lambda x: x.expanding().sum())
df_v3['From Account Amount Paid Count'] = df_v3.groupby('From Account')['Amount Paid'].transform(lambda x: x.expanding().count())

# Create dynamic Min, Mean, Median, Max, Sum & Count for every receiver account ("To Account")
df_v3['To Account Amount Received Min'] = df_v3.groupby('To Account')['Amount Received'].transform(lambda x: x.expanding().min())
df_v3['To Account Amount Received Mean'] = df_v3.groupby('To Account')['Amount Received'].transform(lambda x: x.expanding().mean())
df_v3['To Account Amount Received Median'] = df_v3.groupby('To Account')['Amount Received'].transform(lambda x: x.expanding().median())
df_v3['To Account Amount Received Max'] = df_v3.groupby('To Account')['Amount Received'].transform(lambda x: x.expanding().max())
df_v3['To Account Amount Received Sum'] = df_v3.groupby('To Account')['Amount Received'].transform(lambda x: x.expanding().sum())
df_v3['To Account Amount Received Count'] = df_v3.groupby('To Account')['Amount Received'].transform(lambda x: x.expanding().count())

df_v3.head()
# Out:
#    Timestamp  From Bank From Account  To Bank To Account  Amount Received  \
# 0 2022-09-01        121    8123FB9B0      121  8123FB9B0        12.677957
# 1 2022-09-01      25170    8095AF7C0    25170  8095AF7C0      2977.670116
# 2 2022-09-01      25665    809A7D4B0    24779  809189BA0        74.103124
# 3 2022-09-01      32317    800D4E490    12004  800D4E750     13886.360391
# 4 2022-09-01       1024    800C8D9D0     1024  800C8D9D0        10.330801
#
#   Receiving Currency   Amount Paid Payment Currency Payment Format  ...  \
# 0        Saudi Riyal     12.677957      Saudi Riyal   Reinvestment  ...
# 1    Canadian Dollar   2977.670116  Canadian Dollar   Reinvestment  ...
# 2    Canadian Dollar     74.103124  Canadian Dollar    Credit Card  ...
# 3               Euro  13886.360391             Euro           Wire  ...
# 4               Euro     10.330801             Euro   Reinvestment  ...
#
#    From Account Amount Paid Median  From Account Amount Paid Max  \
# 0                        12.677957                     12.677957
# 1                      2977.670116                   2977.670116
# 2                        74.103124                     74.103124
# 3                     13886.360391                  13886.360391
# 4                        10.330801                     10.330801
#
#    From Account Amount Paid Sum  From Account Amount Paid Count  \
# 0                     12.677957                             1.0
# 1                   2977.670116                             1.0
# 2                     74.103124                             1.0
# 3                  13886.360391                             1.0
# 4                     10.330801                             1.0
#
#    To Account Amount Received Min  To Account Amount Received Mean  \
# 0                       12.677957                        12.677957
# 1                     2977.670116                      2977.670116
# 2                       74.103124                        74.103124
# 3                    13886.360391                     13886.360391
# 4                       10.330801                        10.330801
#
#    To Account Amount Received Median  To Account Amount Received Max  \
# 0                          12.677957                       12.677957
# 1                        2977.670116                     2977.670116
# 2                          74.103124                       74.103124
# 3                       13886.360391                    13886.360391
# 4                          10.330801                       10.330801
#
#    To Account Amount Received Sum  To Account Amount Received Count
# 0                       12.677957                               1.0
# 1                     2977.670116                               1.0
# 2                       74.103124                               1.0
# 3                    13886.360391                               1.0
# 4                       10.330801                               1.0
#
# [5 rows x 39 columns]

# %%
# CHECK RESULTS - Dynmamic variables by a selected account history
pd.set_option('display.max_columns', None)
df_v3_test_from = df_v3[df_v3['From Account'] == '100428780']
df_v3_test_from.head()

df_v3_test_to = df_v3[df_v3['To Account'] == '100428780']
df_v3_test_to.head()
# Out:
#                  Timestamp  From Bank From Account  To Bank To Account  \
# 114023 2022-09-01 00:10:00     313638    804F4AED0       70  100428780
# 124189 2022-09-01 00:11:00     312747    8054CB880       70  100428780
# 139045 2022-09-01 00:12:00     312246    805410180       70  100428780
# 465982 2022-09-01 04:38:00     312830    80536CA40       70  100428780
# 724918 2022-09-01 12:22:00     313167    804CDF110       70  100428780
#
#         Amount Received Receiving Currency  Amount Paid Payment Currency  \
# 114023         0.001380              Rupee     0.001380            Rupee
# 124189         0.001255              Rupee     0.001255            Rupee
# 139045         0.000376              Rupee     0.000376            Rupee
# 465982         0.001004              Rupee     0.001004            Rupee
# 724918         0.005899              Rupee     0.005899            Rupee
#
#        Payment Format  Is Laundering  Digit Sum Amount Received  \
# 114023           Cash              0                          2
# 124189           Cash              0                          1
# 139045           Cash              0                          3
# 465982           Cash              0                          8
# 724918           Cash              0                         11
#
#         Digit Sum Amount Paid  Count Zeros Amount Received  \
# 114023                      2                            5
# 124189                      1                            6
# 139045                      3                            6
# 465982                      8                            6
# 724918                     11                            5
#
#         Count Zeros Amount Paid  From Account Average Digit Sum Paid  \
# 114023                        5                            16.666667
# 124189                        6                            19.000000
# 139045                        6                            23.666667
# 465982                        6                            22.666667
# 724918                        5                            14.333333
#
#         From Account Average Count Zeros Paid  \
# 114023                               5.666667
# 124189                               4.666667
# 139045                               4.666667
# 465982                               4.666667
# 724918                               5.666667
#
#         From Account Average Digit Sum Received  \
# 114023                                      NaN
# 124189                                      NaN
# 139045                                      NaN
# 465982                                      NaN
# 724918                                      NaN
#
#         From Account Average Count Zeros Received  \
# 114023                                        NaN
# 124189                                        NaN
# 139045                                        NaN
# 465982                                        NaN
# 724918                                        NaN
#
#         To Account Average Digit Sum Paid  \
# 114023                          32.097949
# 124189                          32.097949
# 139045                          32.097949
# 465982                          32.097949
# 724918                          32.097949
#
#         To Account Average Count Zeros Paid  \
# 114023                             4.635832
# 124189                             4.635832
# 139045                             4.635832
# 465982                             4.635832
# 724918                             4.635832
#
#         To Account Average Digit Sum Received  \
# 114023                              29.290598
# 124189                              29.290598
# 139045                              29.290598
# 465982                              29.290598
# 724918                              29.290598
#
#         To Account Average Count Zeros Received  \
# 114023                                 4.632479
# 124189                                 4.632479
# 139045                                 4.632479
# 465982                                 4.632479
# 724918                                 4.632479
#
#         From Account Average Zero Digit Ratio Paid  \
# 114023                                    0.601732
# 124189                                    0.528139
# 139045                                    0.552381
# 465982                                    0.528139
# 724918                                    0.571429
#
#         From Account Average Zero Digit Ratio Received  \
# 114023                                             NaN
# 124189                                             NaN
# 139045                                             NaN
# 465982                                             NaN
# 724918                                             NaN
#
#         To Account Average Zero Digit Ratio Paid  \
# 114023                                  0.408176
# 124189                                  0.408176
# 139045                                  0.408176
# 465982                                  0.408176
# 724918                                  0.408176
#
#         To Account Average Zero Digit Ratio Received  \
# 114023                                      0.435559
# 124189                                      0.435559
# 139045                                      0.435559
# 465982                                      0.435559
# 724918                                      0.435559
#
#         From Account Amount Paid Min  From Account Amount Paid Mean  \
# 114023                      0.001380                       0.001380
# 124189                      0.001255                       0.001255
# 139045                      0.000376                       0.000376
# 465982                      0.001004                       0.001004
# 724918                      0.005899                       0.005899
#
#         From Account Amount Paid Median  From Account Amount Paid Max  \
# 114023                         0.001380                      0.001380
# 124189                         0.001255                      0.001255
# 139045                         0.000376                      0.000376
# 465982                         0.001004                      0.001004
# 724918                         0.005899                      0.005899
#
#         From Account Amount Paid Sum  From Account Amount Paid Count  \
# 114023                      0.001380                             1.0
# 124189                      0.001255                             1.0
# 139045                      0.000376                             1.0
# 465982                      0.001004                             1.0
# 724918                      0.005899                             1.0
#
#         To Account Amount Received Min  To Account Amount Received Mean  \
# 114023                        0.001380                         0.001380
# 124189                        0.001255                         0.001318
# 139045                        0.000376                         0.001004
# 465982                        0.000376                         0.001004
# 724918                        0.000376                         0.001983
#
#         To Account Amount Received Median  To Account Amount Received Max  \
# 114023                           0.001380                        0.001380
# 124189                           0.001318                        0.001380
# 139045                           0.001255                        0.001380
# 465982                           0.001130                        0.001380
# 724918                           0.001255                        0.005899
#
#         To Account Amount Received Sum  To Account Amount Received Count
# 114023                        0.001380                               1.0
# 124189                        0.002635                               2.0
# 139045                        0.003012                               3.0
# 465982                        0.004016                               4.0
# 724918                        0.009914                               5.0

# %% [markdown]
# ### V4: Average Sum per Payment Format

# %%
# Calculate average amount paid per payment format grouped by "From Account"
average_paid = df_v3.pivot_table(values='Amount Paid', index='From Account', columns='Payment Format', aggfunc='mean')
average_paid.columns = [f'From Account Average Amount Paid in {col}' for col in average_paid.columns]

# Calculate average amount received per payment format grouped by "To Account"
average_received = df_v3.pivot_table(values='Amount Received', index='To Account', columns='Payment Format', aggfunc='mean')
average_received.columns = [f'To Account Average Amount Received in {col}' for col in average_received.columns]

# Merge with variables "From Account" and "To Account"
df_v4 = pd.merge(df_v3, average_paid, how='left', left_on='From Account', right_index=True)
df_v4 = pd.merge(df_v4, average_received, how='left', left_on='To Account', right_index=True)
df_v4.head()
# Out:
#    Timestamp  From Bank From Account  To Bank To Account  Amount Received  \
# 0 2022-09-01        121    8123FB9B0      121  8123FB9B0        12.677957
# 1 2022-09-01      25170    8095AF7C0    25170  8095AF7C0      2977.670116
# 2 2022-09-01      25665    809A7D4B0    24779  809189BA0        74.103124
# 3 2022-09-01      32317    800D4E490    12004  800D4E750     13886.360391
# 4 2022-09-01       1024    800C8D9D0     1024  800C8D9D0        10.330801
#
#   Receiving Currency   Amount Paid Payment Currency Payment Format  \
# 0        Saudi Riyal     12.677957      Saudi Riyal   Reinvestment
# 1    Canadian Dollar   2977.670116  Canadian Dollar   Reinvestment
# 2    Canadian Dollar     74.103124  Canadian Dollar    Credit Card
# 3               Euro  13886.360391             Euro           Wire
# 4               Euro     10.330801             Euro   Reinvestment
#
#    Is Laundering  Digit Sum Amount Received  Digit Sum Amount Paid  \
# 0              0                         21                     21
# 1              0                         26                     26
# 2              0                         29                     29
# 3              0                         30                     30
# 4              0                         11                     11
#
#    Count Zeros Amount Received  Count Zeros Amount Paid  \
# 0                            4                        4
# 1                            4                        4
# 2                            4                        4
# 3                            5                        5
# 4                            5                        5
#
#    From Account Average Digit Sum Paid  From Account Average Count Zeros Paid  \
# 0                            24.000000                               4.333333
# 1                            19.666667                               4.666667
# 2                            17.700000                               4.700000
# 3                            30.000000                               5.000000
# 4                            19.333333                               4.766667
#
#    From Account Average Digit Sum Received  \
# 0                                26.071429
# 1                                18.500000
# 2                                22.000000
# 3                                      NaN
# 4                                19.250000
#
#    From Account Average Count Zeros Received  \
# 0                                   4.857143
# 1                                   4.000000
# 2                                   6.000000
# 3                                        NaN
# 4                                   4.500000
#
#    To Account Average Digit Sum Paid  To Account Average Count Zeros Paid  \
# 0                          24.000000                             4.333333
# 1                          19.666667                             4.666667
# 2                          27.017544                             4.438596
# 3                          26.000000                             4.888889
# 4                          19.333333                             4.766667
#
#    To Account Average Digit Sum Received  \
# 0                              26.071429
# 1                              18.500000
# 2                              18.463415
# 3                              25.500000
# 4                              19.250000
#
#    To Account Average Count Zeros Received  \
# 0                                 4.857143
# 1                                 4.000000
# 2                                 4.658537
# 3                                 4.500000
# 4                                 4.500000
#
#    From Account Average Zero Digit Ratio Paid  \
# 0                                    0.485185
# 1                                    0.500000
# 2                                    0.582143
# 3                                    0.454545
# 4                                    0.595648
#
#    From Account Average Zero Digit Ratio Received  \
# 0                                        0.488276
# 1                                        0.450000
# 2                                        0.600000
# 3                                             NaN
# 4                                        0.517361
#
#    To Account Average Zero Digit Ratio Paid  \
# 0                                  0.485185
# 1                                  0.500000
# 2                                  0.450642
# 3                                  0.485602
# 4                                  0.595648
#
#    To Account Average Zero Digit Ratio Received  From Account Amount Paid Min  \
# 0                                      0.488276                     12.677957
# 1                                      0.450000                   2977.670116
# 2                                      0.527153                     74.103124
# 3                                      0.458417                  13886.360391
# 4                                      0.517361                     10.330801
#
#    From Account Amount Paid Mean  From Account Amount Paid Median  \
# 0                      12.677957                        12.677957
# 1                    2977.670116                      2977.670116
# 2                      74.103124                        74.103124
# 3                   13886.360391                     13886.360391
# 4                      10.330801                        10.330801
#
#    From Account Amount Paid Max  From Account Amount Paid Sum  \
# 0                     12.677957                     12.677957
# 1                   2977.670116                   2977.670116
# 2                     74.103124                     74.103124
# 3                  13886.360391                  13886.360391
# 4                     10.330801                     10.330801
#
#    From Account Amount Paid Count  To Account Amount Received Min  \
# 0                             1.0                       12.677957
# 1                             1.0                     2977.670116
# 2                             1.0                       74.103124
# 3                             1.0                    13886.360391
# 4                             1.0                       10.330801
#
#    To Account Amount Received Mean  To Account Amount Received Median  \
# 0                        12.677957                          12.677957
# 1                      2977.670116                        2977.670116
# 2                        74.103124                          74.103124
# 3                     13886.360391                       13886.360391
# 4                        10.330801                          10.330801
#
#    To Account Amount Received Max  To Account Amount Received Sum  \
# 0                       12.677957                       12.677957
# 1                     2977.670116                     2977.670116
# 2                       74.103124                       74.103124
# 3                    13886.360391                    13886.360391
# 4                       10.330801                       10.330801
#
#    To Account Amount Received Count  From Account Average Amount Paid in ACH  \
# 0                               1.0                              2058.070954
# 1                               1.0                              2089.542390
# 2                               1.0                                      NaN
# 3                               1.0                                      NaN
# 4                               1.0                                      NaN
#
#    From Account Average Amount Paid in Bitcoin  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    From Account Average Amount Paid in Cash  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                               1876.450105
#
#    From Account Average Amount Paid in Cheque  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                  273.557031
#
#    From Account Average Amount Paid in Credit Card  \
# 0                                              NaN
# 1                                              NaN
# 2                                        63.796792
# 3                                              NaN
# 4                                         0.368601
#
#    From Account Average Amount Paid in Reinvestment  \
# 0                                        113.920650
# 1                                       1493.562942
# 2                                               NaN
# 3                                               NaN
# 4                                        264.361920
#
#    From Account Average Amount Paid in Wire  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                              13886.360391
# 4                                       NaN
#
#    To Account Average Amount Received in ACH  \
# 0                                        NaN
# 1                                        NaN
# 2                                 156.286217
# 3                                        NaN
# 4                                        NaN
#
#    To Account Average Amount Received in Bitcoin  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    To Account Average Amount Received in Cash  \
# 0                                         NaN
# 1                                         NaN
# 2                                  3659.92965
# 3                                         NaN
# 4                                         NaN
#
#    To Account Average Amount Received in Cheque  \
# 0                                  2.543906e+03
# 1                                           NaN
# 2                                  5.899356e+04
# 3                                  1.370731e+06
# 4                                  1.767892e+02
#
#    To Account Average Amount Received in Credit Card  \
# 0                                       27771.013808
# 1                                                NaN
# 2                                          52.150456
# 3                                                NaN
# 4                                                NaN
#
#    To Account Average Amount Received in Reinvestment  \
# 0                                         113.920650
# 1                                        1493.562942
# 2                                       34307.393825
# 3                                        2514.434374
# 4                                         264.361920
#
#    To Account Average Amount Received in Wire
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                13886.360391
# 4                                         NaN

# %%
# CHECK RESULTS - Average sum per payment format by a selected account
df_v4_test_from = df_v4[df_v4['From Account'] == '100428780']
df_v4_test_from_grouped = df_v4_test_from.groupby('Payment Format')['Amount Paid'].mean()
df_v4_test_from_grouped
df_v4_test_from.head()

df_v4_test_to = df_v4[df_v4['To Account'] == '100428780']
df_v4_test_to_grouped = df_v4_test_to.groupby('Payment Format')['Amount Received'].mean()
df_v4_test_to_grouped
df_v4_test_to.head()
# Out:
#                  Timestamp  From Bank From Account  To Bank To Account  \
# 114023 2022-09-01 00:10:00     313638    804F4AED0       70  100428780
# 124189 2022-09-01 00:11:00     312747    8054CB880       70  100428780
# 139045 2022-09-01 00:12:00     312246    805410180       70  100428780
# 465982 2022-09-01 04:38:00     312830    80536CA40       70  100428780
# 724918 2022-09-01 12:22:00     313167    804CDF110       70  100428780
#
#         Amount Received Receiving Currency  Amount Paid Payment Currency  \
# 114023         0.001380              Rupee     0.001380            Rupee
# 124189         0.001255              Rupee     0.001255            Rupee
# 139045         0.000376              Rupee     0.000376            Rupee
# 465982         0.001004              Rupee     0.001004            Rupee
# 724918         0.005899              Rupee     0.005899            Rupee
#
#        Payment Format  Is Laundering  Digit Sum Amount Received  \
# 114023           Cash              0                          2
# 124189           Cash              0                          1
# 139045           Cash              0                          3
# 465982           Cash              0                          8
# 724918           Cash              0                         11
#
#         Digit Sum Amount Paid  Count Zeros Amount Received  \
# 114023                      2                            5
# 124189                      1                            6
# 139045                      3                            6
# 465982                      8                            6
# 724918                     11                            5
#
#         Count Zeros Amount Paid  From Account Average Digit Sum Paid  \
# 114023                        5                            16.666667
# 124189                        6                            19.000000
# 139045                        6                            23.666667
# 465982                        6                            22.666667
# 724918                        5                            14.333333
#
#         From Account Average Count Zeros Paid  \
# 114023                               5.666667
# 124189                               4.666667
# 139045                               4.666667
# 465982                               4.666667
# 724918                               5.666667
#
#         From Account Average Digit Sum Received  \
# 114023                                      NaN
# 124189                                      NaN
# 139045                                      NaN
# 465982                                      NaN
# 724918                                      NaN
#
#         From Account Average Count Zeros Received  \
# 114023                                        NaN
# 124189                                        NaN
# 139045                                        NaN
# 465982                                        NaN
# 724918                                        NaN
#
#         To Account Average Digit Sum Paid  \
# 114023                          32.097949
# 124189                          32.097949
# 139045                          32.097949
# 465982                          32.097949
# 724918                          32.097949
#
#         To Account Average Count Zeros Paid  \
# 114023                             4.635832
# 124189                             4.635832
# 139045                             4.635832
# 465982                             4.635832
# 724918                             4.635832
#
#         To Account Average Digit Sum Received  \
# 114023                              29.290598
# 124189                              29.290598
# 139045                              29.290598
# 465982                              29.290598
# 724918                              29.290598
#
#         To Account Average Count Zeros Received  \
# 114023                                 4.632479
# 124189                                 4.632479
# 139045                                 4.632479
# 465982                                 4.632479
# 724918                                 4.632479
#
#         From Account Average Zero Digit Ratio Paid  \
# 114023                                    0.601732
# 124189                                    0.528139
# 139045                                    0.552381
# 465982                                    0.528139
# 724918                                    0.571429
#
#         From Account Average Zero Digit Ratio Received  \
# 114023                                             NaN
# 124189                                             NaN
# 139045                                             NaN
# 465982                                             NaN
# 724918                                             NaN
#
#         To Account Average Zero Digit Ratio Paid  \
# 114023                                  0.408176
# 124189                                  0.408176
# 139045                                  0.408176
# 465982                                  0.408176
# 724918                                  0.408176
#
#         To Account Average Zero Digit Ratio Received  \
# 114023                                      0.435559
# 124189                                      0.435559
# 139045                                      0.435559
# 465982                                      0.435559
# 724918                                      0.435559
#
#         From Account Amount Paid Min  From Account Amount Paid Mean  \
# 114023                      0.001380                       0.001380
# 124189                      0.001255                       0.001255
# 139045                      0.000376                       0.000376
# 465982                      0.001004                       0.001004
# 724918                      0.005899                       0.005899
#
#         From Account Amount Paid Median  From Account Amount Paid Max  \
# 114023                         0.001380                      0.001380
# 124189                         0.001255                      0.001255
# 139045                         0.000376                      0.000376
# 465982                         0.001004                      0.001004
# 724918                         0.005899                      0.005899
#
#         From Account Amount Paid Sum  From Account Amount Paid Count  \
# 114023                      0.001380                             1.0
# 124189                      0.001255                             1.0
# 139045                      0.000376                             1.0
# 465982                      0.001004                             1.0
# 724918                      0.005899                             1.0
#
#         To Account Amount Received Min  To Account Amount Received Mean  \
# 114023                        0.001380                         0.001380
# 124189                        0.001255                         0.001318
# 139045                        0.000376                         0.001004
# 465982                        0.000376                         0.001004
# 724918                        0.000376                         0.001983
#
#         To Account Amount Received Median  To Account Amount Received Max  \
# 114023                           0.001380                        0.001380
# 124189                           0.001318                        0.001380
# 139045                           0.001255                        0.001380
# 465982                           0.001130                        0.001380
# 724918                           0.001255                        0.005899
#
#         To Account Amount Received Sum  To Account Amount Received Count  \
# 114023                        0.001380                               1.0
# 124189                        0.002635                               2.0
# 139045                        0.003012                               3.0
# 465982                        0.004016                               4.0
# 724918                        0.009914                               5.0
#
#         From Account Average Amount Paid in ACH  \
# 114023                                      NaN
# 124189                               146.786557
# 139045                                87.045796
# 465982                                      NaN
# 724918                                      NaN
#
#         From Account Average Amount Paid in Bitcoin  \
# 114023                                          NaN
# 124189                                          NaN
# 139045                                          NaN
# 465982                                          NaN
# 724918                                          NaN
#
#         From Account Average Amount Paid in Cash  \
# 114023                                  0.001380
# 124189                                  0.001255
# 139045                                  0.000376
# 465982                                  0.001004
# 724918                                  0.005899
#
#         From Account Average Amount Paid in Cheque  \
# 114023                                         NaN
# 124189                                         NaN
# 139045                                         NaN
# 465982                                  767.903376
# 724918                                 1644.310036
#
#         From Account Average Amount Paid in Credit Card  \
# 114023                                       201.295725
# 124189                                              NaN
# 139045                                              NaN
# 465982                                              NaN
# 724918                                              NaN
#
#         From Account Average Amount Paid in Reinvestment  \
# 114023                                               NaN
# 124189                                               NaN
# 139045                                               NaN
# 465982                                               NaN
# 724918                                               NaN
#
#         From Account Average Amount Paid in Wire  \
# 114023                                       NaN
# 124189                                       NaN
# 139045                                       NaN
# 465982                                       NaN
# 724918                                       NaN
#
#         To Account Average Amount Received in ACH  \
# 114023                                        NaN
# 124189                                        NaN
# 139045                                        NaN
# 465982                                        NaN
# 724918                                        NaN
#
#         To Account Average Amount Received in Bitcoin  \
# 114023                                            NaN
# 124189                                            NaN
# 139045                                            NaN
# 465982                                            NaN
# 724918                                            NaN
#
#         To Account Average Amount Received in Cash  \
# 114023                                 1133.886059
# 124189                                 1133.886059
# 139045                                 1133.886059
# 465982                                 1133.886059
# 724918                                 1133.886059
#
#         To Account Average Amount Received in Cheque  \
# 114023                                           NaN
# 124189                                           NaN
# 139045                                           NaN
# 465982                                           NaN
# 724918                                           NaN
#
#         To Account Average Amount Received in Credit Card  \
# 114023                                                NaN
# 124189                                                NaN
# 139045                                                NaN
# 465982                                                NaN
# 724918                                                NaN
#
#         To Account Average Amount Received in Reinvestment  \
# 114023                                                NaN
# 124189                                                NaN
# 139045                                                NaN
# 465982                                                NaN
# 724918                                                NaN
#
#         To Account Average Amount Received in Wire
# 114023                                         NaN
# 124189                                         NaN
# 139045                                         NaN
# 465982                                         NaN
# 724918                                         NaN

# %% [markdown]
# ### V5: Transaction Count

# %%
# Count number of transactions each account received
received_counts = df_v2.groupby('To Account').size().reset_index(name='Received Transaction Count')

# Count number of transactions each account paid
paid_counts = df_v2.groupby('From Account').size().reset_index(name='Paid Transaction Count')

# Merge both datasets into a single data frame
transaction_counts = pd.merge(paid_counts, received_counts, how='outer', left_on='From Account', right_on='To Account')

# Combine the two account IDs in a new variable "Account ID"
transaction_counts['Account ID'] = transaction_counts['From Account'].combine_first(transaction_counts['To Account'])

# Drop redundant columns
transaction_counts = transaction_counts.drop(columns=['From Account', 'To Account'])
transaction_counts.head()
# Out:
#    Paid Transaction Count  Received Transaction Count Account ID
# 0                168672.0                      1084.0  100428660
# 1                103018.0                       653.0  1004286A8
# 2                 18663.0                       108.0  1004286F0
# 3                 13756.0                        98.0  100428738
# 4                 17264.0                       117.0  100428780

# %%
# Merge with variable "From Account"
df_v5 = pd.merge(df_v4, transaction_counts, how='left', left_on='From Account', right_on='Account ID')
df_v5.rename(columns={
    'Paid Transaction Count': 'From Account Paid Transaction Count',
    'Received Transaction Count': 'From Account Received Transaction Count'
}, inplace=True)
df_v5.drop(columns=['Account ID'], inplace=True)

# Merge with variable "To Account"
df_v5 = pd.merge(df_v5, transaction_counts, how='left', left_on='To Account', right_on='Account ID')
df_v5.rename(columns={
    'Paid Transaction Count': 'To Account Paid Transaction Count',
    'Received Transaction Count': 'To Account Received Transaction Count'
}, inplace=True)
df_v5.drop(columns=['Account ID'], inplace=True)
df_v5.head()
# Out:
#    Timestamp  From Bank From Account  To Bank To Account  Amount Received  \
# 0 2022-09-01        121    8123FB9B0      121  8123FB9B0        12.677957
# 1 2022-09-01      25170    8095AF7C0    25170  8095AF7C0      2977.670116
# 2 2022-09-01      25665    809A7D4B0    24779  809189BA0        74.103124
# 3 2022-09-01      32317    800D4E490    12004  800D4E750     13886.360391
# 4 2022-09-01       1024    800C8D9D0     1024  800C8D9D0        10.330801
#
#   Receiving Currency   Amount Paid Payment Currency Payment Format  \
# 0        Saudi Riyal     12.677957      Saudi Riyal   Reinvestment
# 1    Canadian Dollar   2977.670116  Canadian Dollar   Reinvestment
# 2    Canadian Dollar     74.103124  Canadian Dollar    Credit Card
# 3               Euro  13886.360391             Euro           Wire
# 4               Euro     10.330801             Euro   Reinvestment
#
#    Is Laundering  Digit Sum Amount Received  Digit Sum Amount Paid  \
# 0              0                         21                     21
# 1              0                         26                     26
# 2              0                         29                     29
# 3              0                         30                     30
# 4              0                         11                     11
#
#    Count Zeros Amount Received  Count Zeros Amount Paid  \
# 0                            4                        4
# 1                            4                        4
# 2                            4                        4
# 3                            5                        5
# 4                            5                        5
#
#    From Account Average Digit Sum Paid  From Account Average Count Zeros Paid  \
# 0                            24.000000                               4.333333
# 1                            19.666667                               4.666667
# 2                            17.700000                               4.700000
# 3                            30.000000                               5.000000
# 4                            19.333333                               4.766667
#
#    From Account Average Digit Sum Received  \
# 0                                26.071429
# 1                                18.500000
# 2                                22.000000
# 3                                      NaN
# 4                                19.250000
#
#    From Account Average Count Zeros Received  \
# 0                                   4.857143
# 1                                   4.000000
# 2                                   6.000000
# 3                                        NaN
# 4                                   4.500000
#
#    To Account Average Digit Sum Paid  To Account Average Count Zeros Paid  \
# 0                          24.000000                             4.333333
# 1                          19.666667                             4.666667
# 2                          27.017544                             4.438596
# 3                          26.000000                             4.888889
# 4                          19.333333                             4.766667
#
#    To Account Average Digit Sum Received  \
# 0                              26.071429
# 1                              18.500000
# 2                              18.463415
# 3                              25.500000
# 4                              19.250000
#
#    To Account Average Count Zeros Received  \
# 0                                 4.857143
# 1                                 4.000000
# 2                                 4.658537
# 3                                 4.500000
# 4                                 4.500000
#
#    From Account Average Zero Digit Ratio Paid  \
# 0                                    0.485185
# 1                                    0.500000
# 2                                    0.582143
# 3                                    0.454545
# 4                                    0.595648
#
#    From Account Average Zero Digit Ratio Received  \
# 0                                        0.488276
# 1                                        0.450000
# 2                                        0.600000
# 3                                             NaN
# 4                                        0.517361
#
#    To Account Average Zero Digit Ratio Paid  \
# 0                                  0.485185
# 1                                  0.500000
# 2                                  0.450642
# 3                                  0.485602
# 4                                  0.595648
#
#    To Account Average Zero Digit Ratio Received  From Account Amount Paid Min  \
# 0                                      0.488276                     12.677957
# 1                                      0.450000                   2977.670116
# 2                                      0.527153                     74.103124
# 3                                      0.458417                  13886.360391
# 4                                      0.517361                     10.330801
#
#    From Account Amount Paid Mean  From Account Amount Paid Median  \
# 0                      12.677957                        12.677957
# 1                    2977.670116                      2977.670116
# 2                      74.103124                        74.103124
# 3                   13886.360391                     13886.360391
# 4                      10.330801                        10.330801
#
#    From Account Amount Paid Max  From Account Amount Paid Sum  \
# 0                     12.677957                     12.677957
# 1                   2977.670116                   2977.670116
# 2                     74.103124                     74.103124
# 3                  13886.360391                  13886.360391
# 4                     10.330801                     10.330801
#
#    From Account Amount Paid Count  To Account Amount Received Min  \
# 0                             1.0                       12.677957
# 1                             1.0                     2977.670116
# 2                             1.0                       74.103124
# 3                             1.0                    13886.360391
# 4                             1.0                       10.330801
#
#    To Account Amount Received Mean  To Account Amount Received Median  \
# 0                        12.677957                          12.677957
# 1                      2977.670116                        2977.670116
# 2                        74.103124                          74.103124
# 3                     13886.360391                       13886.360391
# 4                        10.330801                          10.330801
#
#    To Account Amount Received Max  To Account Amount Received Sum  \
# 0                       12.677957                       12.677957
# 1                     2977.670116                     2977.670116
# 2                       74.103124                       74.103124
# 3                    13886.360391                    13886.360391
# 4                       10.330801                       10.330801
#
#    To Account Amount Received Count  From Account Average Amount Paid in ACH  \
# 0                               1.0                              2058.070954
# 1                               1.0                              2089.542390
# 2                               1.0                                      NaN
# 3                               1.0                                      NaN
# 4                               1.0                                      NaN
#
#    From Account Average Amount Paid in Bitcoin  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    From Account Average Amount Paid in Cash  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                               1876.450105
#
#    From Account Average Amount Paid in Cheque  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                  273.557031
#
#    From Account Average Amount Paid in Credit Card  \
# 0                                              NaN
# 1                                              NaN
# 2                                        63.796792
# 3                                              NaN
# 4                                         0.368601
#
#    From Account Average Amount Paid in Reinvestment  \
# 0                                        113.920650
# 1                                       1493.562942
# 2                                               NaN
# 3                                               NaN
# 4                                        264.361920
#
#    From Account Average Amount Paid in Wire  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                              13886.360391
# 4                                       NaN
#
#    To Account Average Amount Received in ACH  \
# 0                                        NaN
# 1                                        NaN
# 2                                 156.286217
# 3                                        NaN
# 4                                        NaN
#
#    To Account Average Amount Received in Bitcoin  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    To Account Average Amount Received in Cash  \
# 0                                         NaN
# 1                                         NaN
# 2                                  3659.92965
# 3                                         NaN
# 4                                         NaN
#
#    To Account Average Amount Received in Cheque  \
# 0                                  2.543906e+03
# 1                                           NaN
# 2                                  5.899356e+04
# 3                                  1.370731e+06
# 4                                  1.767892e+02
#
#    To Account Average Amount Received in Credit Card  \
# 0                                       27771.013808
# 1                                                NaN
# 2                                          52.150456
# 3                                                NaN
# 4                                                NaN
#
#    To Account Average Amount Received in Reinvestment  \
# 0                                         113.920650
# 1                                        1493.562942
# 2                                       34307.393825
# 3                                        2514.434374
# 4                                         264.361920
#
#    To Account Average Amount Received in Wire  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                13886.360391
# 4                                         NaN
#
#    From Account Paid Transaction Count  \
# 0                                  3.0
# 1                                  3.0
# 2                                 10.0
# 3                                  1.0
# 4                                 30.0
#
#    From Account Received Transaction Count  To Account Paid Transaction Count  \
# 0                                     14.0                                3.0
# 1                                      2.0                                3.0
# 2                                      1.0                               57.0
# 3                                      NaN                                9.0
# 4                                      4.0                               30.0
#
#    To Account Received Transaction Count
# 0                                   14.0
# 1                                    2.0
# 2                                   41.0
# 3                                    4.0
# 4                                    4.0

# %%
# CHECK RESULTS - Transaction counts by a selected account
df_v5_test_from = df_v5[df_v5['From Account'] == '100428780']
df_v5_test_from.describe()

df_v5_test_to = df_v5[df_v5['To Account'] == '100428780']
df_v5_test_to.describe()
# Out:
#            From Bank  To Bank  Amount Received   Amount Paid  Is Laundering  \
# count     117.000000    117.0       117.000000    117.000000          117.0
# mean   308834.717949     70.0      1133.886059   1133.886059            0.0
# std     41180.572256      0.0      5194.969419   5194.969419            0.0
# min        16.000000     70.0         0.000376      0.000376            0.0
# 25%    312747.000000     70.0       146.534302    146.534302            0.0
# 50%    313279.000000     70.0       258.135805    258.135805            0.0
# 75%    314355.000000     70.0       548.852413    548.852413            0.0
# max    349651.000000     70.0     40011.039030  40011.039030            0.0
#
#        Digit Sum Amount Received  Digit Sum Amount Paid  \
# count                 117.000000             117.000000
# mean                   29.290598              29.290598
# std                     9.381805               9.381805
# min                     1.000000               1.000000
# 25%                    25.000000              25.000000
# 50%                    29.000000              29.000000
# 75%                    36.000000              36.000000
# max                    45.000000              45.000000
#
#        Count Zeros Amount Received  Count Zeros Amount Paid  \
# count                   117.000000               117.000000
# mean                      4.632479                 4.632479
# std                       0.749693                 0.749693
# min                       4.000000                 4.000000
# 25%                       4.000000                 4.000000
# 50%                       4.000000                 4.000000
# 75%                       5.000000                 5.000000
# max                       7.000000                 7.000000
#
#        From Account Average Digit Sum Paid  \
# count                           117.000000
# mean                             25.791311
# std                               8.504403
# min                               5.666667
# 25%                              20.000000
# 50%                              25.333333
# 75%                              30.000000
# max                              45.000000
#
#        From Account Average Count Zeros Paid  \
# count                             117.000000
# mean                                4.770522
# std                                 0.628768
# min                                 4.000000
# 25%                                 4.333333
# 50%                                 4.666667
# 75%                                 5.333333
# max                                 6.666667
#
#        From Account Average Digit Sum Received  \
# count                                     2.00
# mean                                     28.48
# std                                       0.00
# min                                      28.48
# 25%                                      28.48
# 50%                                      28.48
# 75%                                      28.48
# max                                      28.48
#
#        From Account Average Count Zeros Received  \
# count                                       2.00
# mean                                        5.32
# std                                         0.00
# min                                         5.32
# 25%                                         5.32
# 50%                                         5.32
# 75%                                         5.32
# max                                         5.32
#
#        To Account Average Digit Sum Paid  To Account Average Count Zeros Paid  \
# count                       1.170000e+02                         1.170000e+02
# mean                        3.209795e+01                         4.635832e+00
# std                         9.990384e-14                         4.459993e-15
# min                         3.209795e+01                         4.635832e+00
# 25%                         3.209795e+01                         4.635832e+00
# 50%                         3.209795e+01                         4.635832e+00
# 75%                         3.209795e+01                         4.635832e+00
# max                         3.209795e+01                         4.635832e+00
#
#        To Account Average Digit Sum Received  \
# count                           1.170000e+02
# mean                            2.929060e+01
# std                             2.854395e-14
# min                             2.929060e+01
# 25%                             2.929060e+01
# 50%                             2.929060e+01
# 75%                             2.929060e+01
# max                             2.929060e+01
#
#        To Account Average Count Zeros Received  \
# count                             1.170000e+02
# mean                              4.632479e+00
# std                               3.567994e-15
# min                               4.632479e+00
# 25%                               4.632479e+00
# 50%                               4.632479e+00
# 75%                               4.632479e+00
# max                               4.632479e+00
#
#        From Account Average Zero Digit Ratio Paid  \
# count                                  117.000000
# mean                                     0.490891
# std                                      0.086586
# min                                      0.363636
# 25%                                      0.444444
# 50%                                      0.480519
# 75%                                      0.552381
# max                                      0.709957
#
#        From Account Average Zero Digit Ratio Received  \
# count                                        2.000000
# mean                                         0.447532
# std                                          0.000000
# min                                          0.447532
# 25%                                          0.447532
# 50%                                          0.447532
# 75%                                          0.447532
# max                                          0.447532
#
#        To Account Average Zero Digit Ratio Paid  \
# count                              1.170000e+02
# mean                               4.081758e-01
# std                                8.362486e-16
# min                                4.081758e-01
# 25%                                4.081758e-01
# 50%                                4.081758e-01
# 75%                                4.081758e-01
# max                                4.081758e-01
#
#        To Account Average Zero Digit Ratio Received  \
# count                                  1.170000e+02
# mean                                   4.355594e-01
# std                                    9.477485e-16
# min                                    4.355594e-01
# 25%                                    4.355594e-01
# 50%                                    4.355594e-01
# 75%                                    4.355594e-01
# max                                    4.355594e-01
#
#        From Account Amount Paid Min  From Account Amount Paid Mean  \
# count                    117.000000                     117.000000
# mean                     129.080259                     815.917475
# std                      188.562429                    4051.570828
# min                        0.000126                       0.000376
# 25%                        0.000628                     100.057699
# 50%                        0.005773                     201.384202
# 75%                      230.124581                     432.416525
# max                      565.707816                   40220.372144
#
#        From Account Amount Paid Median  From Account Amount Paid Max  \
# count                       117.000000                    117.000000
# mean                        423.021237                   8694.987857
# std                         658.701679                  62734.303088
# min                           0.000376                      0.000376
# 25%                         122.537886                    146.534302
# 50%                         230.124581                    258.135805
# 75%                         511.738047                    548.852413
# max                        4768.060256                 482335.494231
#
#        From Account Amount Paid Sum  From Account Amount Paid Count  \
# count                  1.170000e+02                       117.00000
# mean                   3.079626e+04                         3.25641
# std                    2.339761e+05                        10.97030
# min                    3.765000e-04                         1.00000
# 25%                    1.972056e+02                         1.00000
# 50%                    3.770467e+02                         2.00000
# 75%                    7.398544e+02                         3.00000
# max                    2.116485e+06                       116.00000
#
#        To Account Amount Received Min  To Account Amount Received Mean  \
# count                      117.000000                       117.000000
# mean                         0.000393                       752.697378
# std                          0.000123                       390.365535
# min                          0.000376                         0.001004
# 25%                          0.000376                       351.821534
# 50%                          0.000376                       865.030902
# 75%                          0.000376                      1087.415400
# max                          0.001380                      1332.513665
#
#        To Account Amount Received Median  To Account Amount Received Max  \
# count                         117.000000                      117.000000
# mean                          212.283333                    26526.107806
# std                            78.188492                    18444.188785
# min                             0.001130                        0.001380
# 25%                           200.115021                     2026.991790
# 50%                           249.990227                    40011.039030
# 75%                           254.063016                    40011.039030
# max                           291.928562                    40011.039030
#
#        To Account Amount Received Sum  To Account Amount Received Count  \
# count                      117.000000                        117.000000
# mean                     53928.224591                         59.000000
# std                      39049.911301                         33.919021
# min                          0.001380                          1.000000
# 25%                      10286.428913                         30.000000
# 50%                      65841.652465                         59.000000
# 75%                      76802.870783                         88.000000
# max                     132664.668872                        117.000000
#
#        From Account Average Amount Paid in ACH  \
# count                                14.000000
# mean                               7576.695353
# std                               19210.139283
# min                                   0.000126
# 25%                                   0.000282
# 50%                                   0.000376
# 75%                                  65.284504
# max                               52919.949536
#
#        From Account Average Amount Paid in Bitcoin  \
# count                                          0.0
# mean                                           NaN
# std                                            NaN
# min                                            NaN
# 25%                                            NaN
# 50%                                            NaN
# 75%                                            NaN
# max                                            NaN
#
#        From Account Average Amount Paid in Cash  \
# count                                117.000000
# mean                                 685.540440
# std                                 1891.576814
# min                                    0.000376
# 25%                                  146.534302
# 50%                                  258.135805
# 75%                                  538.172363
# max                                13986.068071
#
#        From Account Average Amount Paid in Cheque  \
# count                                   52.000000
# mean                                   423.584535
# std                                   1911.365473
# min                                      0.000126
# 25%                                      0.000502
# 50%                                      0.000941
# 75%                                      0.004392
# max                                   9807.033854
#
#        From Account Average Amount Paid in Credit Card  \
# count                                         3.000000
# mean                                       1725.674976
# std                                        1320.151156
# min                                         201.295725
# 25%                                        1344.580163
# 50%                                        2487.864601
# 75%                                        2487.864601
# max                                        2487.864601
#
#        From Account Average Amount Paid in Reinvestment  \
# count                                          2.000000
# mean                                      245802.832905
# std                                            0.000000
# min                                       245802.832905
# 25%                                       245802.832905
# 50%                                       245802.832905
# 75%                                       245802.832905
# max                                       245802.832905
#
#        From Account Average Amount Paid in Wire  \
# count                                  2.000000
# mean                              145577.290832
# std                                    0.000000
# min                               145577.290832
# 25%                               145577.290832
# 50%                               145577.290832
# 75%                               145577.290832
# max                               145577.290832
#
#        To Account Average Amount Received in ACH  \
# count                                        0.0
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        To Account Average Amount Received in Bitcoin  \
# count                                            0.0
# mean                                             NaN
# std                                              NaN
# min                                              NaN
# 25%                                              NaN
# 50%                                              NaN
# 75%                                              NaN
# max                                              NaN
#
#        To Account Average Amount Received in Cash  \
# count                                1.170000e+02
# mean                                 1.133886e+03
# std                                  1.370110e-12
# min                                  1.133886e+03
# 25%                                  1.133886e+03
# 50%                                  1.133886e+03
# 75%                                  1.133886e+03
# max                                  1.133886e+03
#
#        To Account Average Amount Received in Cheque  \
# count                                           0.0
# mean                                            NaN
# std                                             NaN
# min                                             NaN
# 25%                                             NaN
# 50%                                             NaN
# 75%                                             NaN
# max                                             NaN
#
#        To Account Average Amount Received in Credit Card  \
# count                                                0.0
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
#        To Account Average Amount Received in Reinvestment  \
# count                                                0.0
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
#        To Account Average Amount Received in Wire  \
# count                                         0.0
# mean                                          NaN
# std                                           NaN
# min                                           NaN
# 25%                                           NaN
# 50%                                           NaN
# 75%                                           NaN
# max                                           NaN
#
#        From Account Paid Transaction Count  \
# count                           117.000000
# mean                              4.709402
# std                              16.336473
# min                               2.000000
# 25%                               2.000000
# 50%                               3.000000
# 75%                               3.000000
# max                             128.000000
#
#        From Account Received Transaction Count  \
# count                                      2.0
# mean                                      25.0
# std                                        0.0
# min                                       25.0
# 25%                                       25.0
# 50%                                       25.0
# 75%                                       25.0
# max                                       25.0
#
#        To Account Paid Transaction Count  \
# count                              117.0
# mean                             17264.0
# std                                  0.0
# min                              17264.0
# 25%                              17264.0
# 50%                              17264.0
# 75%                              17264.0
# max                              17264.0
#
#        To Account Received Transaction Count
# count                                  117.0
# mean                                   117.0
# std                                      0.0
# min                                    117.0
# 25%                                    117.0
# 50%                                    117.0
# 75%                                    117.0
# max                                    117.0

# %% [markdown]
# ### V6: Standard Deviations & Average Amounts

# %%
# Calculate the average and standard deviation of the amount paid by each account
paid_stats = df_v2.groupby('From Account')['Amount Paid'].agg(['mean', 'std']).reset_index()
paid_stats.rename(columns={
    'mean': 'Average Amount Paid',
    'std': 'Std Dev Amount Paid'
}, inplace=True)

# Calculate the average and standard deviation of the amount received by each account
received_stats = df_v2.groupby('To Account')['Amount Received'].agg(['mean', 'std']).reset_index()
received_stats.rename(columns={
    'mean': 'Average Amount Received',
    'std': 'Std Dev Amount Received'
}, inplace=True)

# Merge both data sets into a single data frame
account_stats = pd.merge(paid_stats, received_stats, how='outer', left_on='From Account', right_on='To Account')

# Combine the two account IDs in a new variable "Account ID"
account_stats['Account ID'] = account_stats['From Account'].combine_first(account_stats['To Account'])

# Drop redundant columns
account_stats = account_stats.drop(columns=['From Account', 'To Account'])
account_stats.head()
# Out:
#    Average Amount Paid  Std Dev Amount Paid  Average Amount Received  \
# 0        312810.017132         8.093752e+06               442.430618
# 1        252099.955717         5.855185e+06               382.928768
# 2        190859.017711         2.860530e+06               339.660077
# 3        134357.055367         2.984029e+06               458.676425
# 4        271829.699056         5.405056e+06              1133.886059
#
#    Std Dev Amount Received Account ID
# 0               637.651237  100428660
# 1               580.761371  1004286A8
# 2               417.590047  1004286F0
# 3               679.765108  100428738
# 4              5194.969419  100428780

# %%
# Merge with variable "From Account"
df_v6 = pd.merge(df_v5, account_stats, how='left', left_on='From Account', right_on='Account ID')
df_v6.rename(columns={
    'Average Amount Paid': 'From Account Average Amount Paid',
    'Std Dev Amount Paid': 'From Account Std Dev Amount Paid',
    'Average Amount Received': 'From Account Average Amount Received',
    'Std Dev Amount Received': 'From Account Std Dev Amount Received'
}, inplace=True)
df_v6.drop(columns=['Account ID'], inplace=True)

# Merge with variable "To Account"
df_v6 = pd.merge(df_v6, account_stats, how='left', left_on='To Account', right_on='Account ID')
df_v6.rename(columns={
    'Average Amount Paid': 'To Account Average Amount Paid',
    'Std Dev Amount Paid': 'To Account Std Dev Amount Paid',
    'Average Amount Received': 'To Account Average Amount Received',
    'Std Dev Amount Received': 'To Account Std Dev Amount Received'
}, inplace=True)
df_v6.drop(columns=['Account ID'], inplace=True)
df_v6.head()
# Out:
#    Timestamp  From Bank From Account  To Bank To Account  Amount Received  \
# 0 2022-09-01        121    8123FB9B0      121  8123FB9B0        12.677957
# 1 2022-09-01      25170    8095AF7C0    25170  8095AF7C0      2977.670116
# 2 2022-09-01      25665    809A7D4B0    24779  809189BA0        74.103124
# 3 2022-09-01      32317    800D4E490    12004  800D4E750     13886.360391
# 4 2022-09-01       1024    800C8D9D0     1024  800C8D9D0        10.330801
#
#   Receiving Currency   Amount Paid Payment Currency Payment Format  \
# 0        Saudi Riyal     12.677957      Saudi Riyal   Reinvestment
# 1    Canadian Dollar   2977.670116  Canadian Dollar   Reinvestment
# 2    Canadian Dollar     74.103124  Canadian Dollar    Credit Card
# 3               Euro  13886.360391             Euro           Wire
# 4               Euro     10.330801             Euro   Reinvestment
#
#    Is Laundering  Digit Sum Amount Received  Digit Sum Amount Paid  \
# 0              0                         21                     21
# 1              0                         26                     26
# 2              0                         29                     29
# 3              0                         30                     30
# 4              0                         11                     11
#
#    Count Zeros Amount Received  Count Zeros Amount Paid  \
# 0                            4                        4
# 1                            4                        4
# 2                            4                        4
# 3                            5                        5
# 4                            5                        5
#
#    From Account Average Digit Sum Paid  From Account Average Count Zeros Paid  \
# 0                            24.000000                               4.333333
# 1                            19.666667                               4.666667
# 2                            17.700000                               4.700000
# 3                            30.000000                               5.000000
# 4                            19.333333                               4.766667
#
#    From Account Average Digit Sum Received  \
# 0                                26.071429
# 1                                18.500000
# 2                                22.000000
# 3                                      NaN
# 4                                19.250000
#
#    From Account Average Count Zeros Received  \
# 0                                   4.857143
# 1                                   4.000000
# 2                                   6.000000
# 3                                        NaN
# 4                                   4.500000
#
#    To Account Average Digit Sum Paid  To Account Average Count Zeros Paid  \
# 0                          24.000000                             4.333333
# 1                          19.666667                             4.666667
# 2                          27.017544                             4.438596
# 3                          26.000000                             4.888889
# 4                          19.333333                             4.766667
#
#    To Account Average Digit Sum Received  \
# 0                              26.071429
# 1                              18.500000
# 2                              18.463415
# 3                              25.500000
# 4                              19.250000
#
#    To Account Average Count Zeros Received  \
# 0                                 4.857143
# 1                                 4.000000
# 2                                 4.658537
# 3                                 4.500000
# 4                                 4.500000
#
#    From Account Average Zero Digit Ratio Paid  \
# 0                                    0.485185
# 1                                    0.500000
# 2                                    0.582143
# 3                                    0.454545
# 4                                    0.595648
#
#    From Account Average Zero Digit Ratio Received  \
# 0                                        0.488276
# 1                                        0.450000
# 2                                        0.600000
# 3                                             NaN
# 4                                        0.517361
#
#    To Account Average Zero Digit Ratio Paid  \
# 0                                  0.485185
# 1                                  0.500000
# 2                                  0.450642
# 3                                  0.485602
# 4                                  0.595648
#
#    To Account Average Zero Digit Ratio Received  From Account Amount Paid Min  \
# 0                                      0.488276                     12.677957
# 1                                      0.450000                   2977.670116
# 2                                      0.527153                     74.103124
# 3                                      0.458417                  13886.360391
# 4                                      0.517361                     10.330801
#
#    From Account Amount Paid Mean  From Account Amount Paid Median  \
# 0                      12.677957                        12.677957
# 1                    2977.670116                      2977.670116
# 2                      74.103124                        74.103124
# 3                   13886.360391                     13886.360391
# 4                      10.330801                        10.330801
#
#    From Account Amount Paid Max  From Account Amount Paid Sum  \
# 0                     12.677957                     12.677957
# 1                   2977.670116                   2977.670116
# 2                     74.103124                     74.103124
# 3                  13886.360391                  13886.360391
# 4                     10.330801                     10.330801
#
#    From Account Amount Paid Count  To Account Amount Received Min  \
# 0                             1.0                       12.677957
# 1                             1.0                     2977.670116
# 2                             1.0                       74.103124
# 3                             1.0                    13886.360391
# 4                             1.0                       10.330801
#
#    To Account Amount Received Mean  To Account Amount Received Median  \
# 0                        12.677957                          12.677957
# 1                      2977.670116                        2977.670116
# 2                        74.103124                          74.103124
# 3                     13886.360391                       13886.360391
# 4                        10.330801                          10.330801
#
#    To Account Amount Received Max  To Account Amount Received Sum  \
# 0                       12.677957                       12.677957
# 1                     2977.670116                     2977.670116
# 2                       74.103124                       74.103124
# 3                    13886.360391                    13886.360391
# 4                       10.330801                       10.330801
#
#    To Account Amount Received Count  From Account Average Amount Paid in ACH  \
# 0                               1.0                              2058.070954
# 1                               1.0                              2089.542390
# 2                               1.0                                      NaN
# 3                               1.0                                      NaN
# 4                               1.0                                      NaN
#
#    From Account Average Amount Paid in Bitcoin  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    From Account Average Amount Paid in Cash  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                               1876.450105
#
#    From Account Average Amount Paid in Cheque  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                  273.557031
#
#    From Account Average Amount Paid in Credit Card  \
# 0                                              NaN
# 1                                              NaN
# 2                                        63.796792
# 3                                              NaN
# 4                                         0.368601
#
#    From Account Average Amount Paid in Reinvestment  \
# 0                                        113.920650
# 1                                       1493.562942
# 2                                               NaN
# 3                                               NaN
# 4                                        264.361920
#
#    From Account Average Amount Paid in Wire  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                              13886.360391
# 4                                       NaN
#
#    To Account Average Amount Received in ACH  \
# 0                                        NaN
# 1                                        NaN
# 2                                 156.286217
# 3                                        NaN
# 4                                        NaN
#
#    To Account Average Amount Received in Bitcoin  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    To Account Average Amount Received in Cash  \
# 0                                         NaN
# 1                                         NaN
# 2                                  3659.92965
# 3                                         NaN
# 4                                         NaN
#
#    To Account Average Amount Received in Cheque  \
# 0                                  2.543906e+03
# 1                                           NaN
# 2                                  5.899356e+04
# 3                                  1.370731e+06
# 4                                  1.767892e+02
#
#    To Account Average Amount Received in Credit Card  \
# 0                                       27771.013808
# 1                                                NaN
# 2                                          52.150456
# 3                                                NaN
# 4                                                NaN
#
#    To Account Average Amount Received in Reinvestment  \
# 0                                         113.920650
# 1                                        1493.562942
# 2                                       34307.393825
# 3                                        2514.434374
# 4                                         264.361920
#
#    To Account Average Amount Received in Wire  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                13886.360391
# 4                                         NaN
#
#    From Account Paid Transaction Count  \
# 0                                  3.0
# 1                                  3.0
# 2                                 10.0
# 3                                  1.0
# 4                                 30.0
#
#    From Account Received Transaction Count  To Account Paid Transaction Count  \
# 0                                     14.0                                3.0
# 1                                      2.0                                3.0
# 2                                      1.0                               57.0
# 3                                      NaN                                9.0
# 4                                      4.0                               30.0
#
#    To Account Received Transaction Count  From Account Average Amount Paid  \
# 0                                   14.0                        761.970751
# 1                                    2.0                       1692.222758
# 2                                   41.0                         63.796792
# 3                                    4.0                      13886.360391
# 4                                    4.0                        583.208441
#
#    From Account Std Dev Amount Paid  From Account Average Amount Received  \
# 0                       1127.012371                           3998.701632
# 1                       1523.473423                           1493.562942
# 2                         85.324934                           2089.542390
# 3                               NaN                                   NaN
# 4                        761.247984                            220.575561
#
#    From Account Std Dev Amount Received  To Account Average Amount Paid  \
# 0                           7731.948289                      761.970751
# 1                           2098.844493                     1692.222758
# 2                                   NaN                     6466.005467
# 3                                   NaN                    32673.804392
# 4                            213.488954                      583.208441
#
#    To Account Std Dev Amount Paid  To Account Average Amount Received  \
# 0                     1127.012371                         3998.701632
# 1                     1523.473423                         1493.562942
# 2                    11491.606058                        13844.942578
# 3                    39634.853693                       347411.581432
# 4                      761.247984                          220.575561
#
#    To Account Std Dev Amount Received
# 0                         7731.948289
# 1                         2098.844493
# 2                        69680.093067
# 3                       682237.153093
# 4                          213.488954

# %%
# CHECK RESULTS - Standard deviations and average amounts by a selected account
df_v6_test_from = df_v6[df_v6['From Account'] == '100428780']
df_v6_test_from.describe()

df_v6_test_to = df_v6[df_v6['To Account'] == '100428780']
df_v6_test_to.describe()
# Out:
#            From Bank  To Bank  Amount Received   Amount Paid  Is Laundering  \
# count     117.000000    117.0       117.000000    117.000000          117.0
# mean   308834.717949     70.0      1133.886059   1133.886059            0.0
# std     41180.572256      0.0      5194.969419   5194.969419            0.0
# min        16.000000     70.0         0.000376      0.000376            0.0
# 25%    312747.000000     70.0       146.534302    146.534302            0.0
# 50%    313279.000000     70.0       258.135805    258.135805            0.0
# 75%    314355.000000     70.0       548.852413    548.852413            0.0
# max    349651.000000     70.0     40011.039030  40011.039030            0.0
#
#        Digit Sum Amount Received  Digit Sum Amount Paid  \
# count                 117.000000             117.000000
# mean                   29.290598              29.290598
# std                     9.381805               9.381805
# min                     1.000000               1.000000
# 25%                    25.000000              25.000000
# 50%                    29.000000              29.000000
# 75%                    36.000000              36.000000
# max                    45.000000              45.000000
#
#        Count Zeros Amount Received  Count Zeros Amount Paid  \
# count                   117.000000               117.000000
# mean                      4.632479                 4.632479
# std                       0.749693                 0.749693
# min                       4.000000                 4.000000
# 25%                       4.000000                 4.000000
# 50%                       4.000000                 4.000000
# 75%                       5.000000                 5.000000
# max                       7.000000                 7.000000
#
#        From Account Average Digit Sum Paid  \
# count                           117.000000
# mean                             25.791311
# std                               8.504403
# min                               5.666667
# 25%                              20.000000
# 50%                              25.333333
# 75%                              30.000000
# max                              45.000000
#
#        From Account Average Count Zeros Paid  \
# count                             117.000000
# mean                                4.770522
# std                                 0.628768
# min                                 4.000000
# 25%                                 4.333333
# 50%                                 4.666667
# 75%                                 5.333333
# max                                 6.666667
#
#        From Account Average Digit Sum Received  \
# count                                     2.00
# mean                                     28.48
# std                                       0.00
# min                                      28.48
# 25%                                      28.48
# 50%                                      28.48
# 75%                                      28.48
# max                                      28.48
#
#        From Account Average Count Zeros Received  \
# count                                       2.00
# mean                                        5.32
# std                                         0.00
# min                                         5.32
# 25%                                         5.32
# 50%                                         5.32
# 75%                                         5.32
# max                                         5.32
#
#        To Account Average Digit Sum Paid  To Account Average Count Zeros Paid  \
# count                       1.170000e+02                         1.170000e+02
# mean                        3.209795e+01                         4.635832e+00
# std                         9.990384e-14                         4.459993e-15
# min                         3.209795e+01                         4.635832e+00
# 25%                         3.209795e+01                         4.635832e+00
# 50%                         3.209795e+01                         4.635832e+00
# 75%                         3.209795e+01                         4.635832e+00
# max                         3.209795e+01                         4.635832e+00
#
#        To Account Average Digit Sum Received  \
# count                           1.170000e+02
# mean                            2.929060e+01
# std                             2.854395e-14
# min                             2.929060e+01
# 25%                             2.929060e+01
# 50%                             2.929060e+01
# 75%                             2.929060e+01
# max                             2.929060e+01
#
#        To Account Average Count Zeros Received  \
# count                             1.170000e+02
# mean                              4.632479e+00
# std                               3.567994e-15
# min                               4.632479e+00
# 25%                               4.632479e+00
# 50%                               4.632479e+00
# 75%                               4.632479e+00
# max                               4.632479e+00
#
#        From Account Average Zero Digit Ratio Paid  \
# count                                  117.000000
# mean                                     0.490891
# std                                      0.086586
# min                                      0.363636
# 25%                                      0.444444
# 50%                                      0.480519
# 75%                                      0.552381
# max                                      0.709957
#
#        From Account Average Zero Digit Ratio Received  \
# count                                        2.000000
# mean                                         0.447532
# std                                          0.000000
# min                                          0.447532
# 25%                                          0.447532
# 50%                                          0.447532
# 75%                                          0.447532
# max                                          0.447532
#
#        To Account Average Zero Digit Ratio Paid  \
# count                              1.170000e+02
# mean                               4.081758e-01
# std                                8.362486e-16
# min                                4.081758e-01
# 25%                                4.081758e-01
# 50%                                4.081758e-01
# 75%                                4.081758e-01
# max                                4.081758e-01
#
#        To Account Average Zero Digit Ratio Received  \
# count                                  1.170000e+02
# mean                                   4.355594e-01
# std                                    9.477485e-16
# min                                    4.355594e-01
# 25%                                    4.355594e-01
# 50%                                    4.355594e-01
# 75%                                    4.355594e-01
# max                                    4.355594e-01
#
#        From Account Amount Paid Min  From Account Amount Paid Mean  \
# count                    117.000000                     117.000000
# mean                     129.080259                     815.917475
# std                      188.562429                    4051.570828
# min                        0.000126                       0.000376
# 25%                        0.000628                     100.057699
# 50%                        0.005773                     201.384202
# 75%                      230.124581                     432.416525
# max                      565.707816                   40220.372144
#
#        From Account Amount Paid Median  From Account Amount Paid Max  \
# count                       117.000000                    117.000000
# mean                        423.021237                   8694.987857
# std                         658.701679                  62734.303088
# min                           0.000376                      0.000376
# 25%                         122.537886                    146.534302
# 50%                         230.124581                    258.135805
# 75%                         511.738047                    548.852413
# max                        4768.060256                 482335.494231
#
#        From Account Amount Paid Sum  From Account Amount Paid Count  \
# count                  1.170000e+02                       117.00000
# mean                   3.079626e+04                         3.25641
# std                    2.339761e+05                        10.97030
# min                    3.765000e-04                         1.00000
# 25%                    1.972056e+02                         1.00000
# 50%                    3.770467e+02                         2.00000
# 75%                    7.398544e+02                         3.00000
# max                    2.116485e+06                       116.00000
#
#        To Account Amount Received Min  To Account Amount Received Mean  \
# count                      117.000000                       117.000000
# mean                         0.000393                       752.697378
# std                          0.000123                       390.365535
# min                          0.000376                         0.001004
# 25%                          0.000376                       351.821534
# 50%                          0.000376                       865.030902
# 75%                          0.000376                      1087.415400
# max                          0.001380                      1332.513665
#
#        To Account Amount Received Median  To Account Amount Received Max  \
# count                         117.000000                      117.000000
# mean                          212.283333                    26526.107806
# std                            78.188492                    18444.188785
# min                             0.001130                        0.001380
# 25%                           200.115021                     2026.991790
# 50%                           249.990227                    40011.039030
# 75%                           254.063016                    40011.039030
# max                           291.928562                    40011.039030
#
#        To Account Amount Received Sum  To Account Amount Received Count  \
# count                      117.000000                        117.000000
# mean                     53928.224591                         59.000000
# std                      39049.911301                         33.919021
# min                          0.001380                          1.000000
# 25%                      10286.428913                         30.000000
# 50%                      65841.652465                         59.000000
# 75%                      76802.870783                         88.000000
# max                     132664.668872                        117.000000
#
#        From Account Average Amount Paid in ACH  \
# count                                14.000000
# mean                               7576.695353
# std                               19210.139283
# min                                   0.000126
# 25%                                   0.000282
# 50%                                   0.000376
# 75%                                  65.284504
# max                               52919.949536
#
#        From Account Average Amount Paid in Bitcoin  \
# count                                          0.0
# mean                                           NaN
# std                                            NaN
# min                                            NaN
# 25%                                            NaN
# 50%                                            NaN
# 75%                                            NaN
# max                                            NaN
#
#        From Account Average Amount Paid in Cash  \
# count                                117.000000
# mean                                 685.540440
# std                                 1891.576814
# min                                    0.000376
# 25%                                  146.534302
# 50%                                  258.135805
# 75%                                  538.172363
# max                                13986.068071
#
#        From Account Average Amount Paid in Cheque  \
# count                                   52.000000
# mean                                   423.584535
# std                                   1911.365473
# min                                      0.000126
# 25%                                      0.000502
# 50%                                      0.000941
# 75%                                      0.004392
# max                                   9807.033854
#
#        From Account Average Amount Paid in Credit Card  \
# count                                         3.000000
# mean                                       1725.674976
# std                                        1320.151156
# min                                         201.295725
# 25%                                        1344.580163
# 50%                                        2487.864601
# 75%                                        2487.864601
# max                                        2487.864601
#
#        From Account Average Amount Paid in Reinvestment  \
# count                                          2.000000
# mean                                      245802.832905
# std                                            0.000000
# min                                       245802.832905
# 25%                                       245802.832905
# 50%                                       245802.832905
# 75%                                       245802.832905
# max                                       245802.832905
#
#        From Account Average Amount Paid in Wire  \
# count                                  2.000000
# mean                              145577.290832
# std                                    0.000000
# min                               145577.290832
# 25%                               145577.290832
# 50%                               145577.290832
# 75%                               145577.290832
# max                               145577.290832
#
#        To Account Average Amount Received in ACH  \
# count                                        0.0
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        To Account Average Amount Received in Bitcoin  \
# count                                            0.0
# mean                                             NaN
# std                                              NaN
# min                                              NaN
# 25%                                              NaN
# 50%                                              NaN
# 75%                                              NaN
# max                                              NaN
#
#        To Account Average Amount Received in Cash  \
# count                                1.170000e+02
# mean                                 1.133886e+03
# std                                  1.370110e-12
# min                                  1.133886e+03
# 25%                                  1.133886e+03
# 50%                                  1.133886e+03
# 75%                                  1.133886e+03
# max                                  1.133886e+03
#
#        To Account Average Amount Received in Cheque  \
# count                                           0.0
# mean                                            NaN
# std                                             NaN
# min                                             NaN
# 25%                                             NaN
# 50%                                             NaN
# 75%                                             NaN
# max                                             NaN
#
#        To Account Average Amount Received in Credit Card  \
# count                                                0.0
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
#        To Account Average Amount Received in Reinvestment  \
# count                                                0.0
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
#        To Account Average Amount Received in Wire  \
# count                                         0.0
# mean                                          NaN
# std                                           NaN
# min                                           NaN
# 25%                                           NaN
# 50%                                           NaN
# 75%                                           NaN
# max                                           NaN
#
#        From Account Paid Transaction Count  \
# count                           117.000000
# mean                              4.709402
# std                              16.336473
# min                               2.000000
# 25%                               2.000000
# 50%                               3.000000
# 75%                               3.000000
# max                             128.000000
#
#        From Account Received Transaction Count  \
# count                                      2.0
# mean                                      25.0
# std                                        0.0
# min                                       25.0
# 25%                                       25.0
# 50%                                       25.0
# 75%                                       25.0
# max                                       25.0
#
#        To Account Paid Transaction Count  \
# count                              117.0
# mean                             17264.0
# std                                  0.0
# min                              17264.0
# 25%                              17264.0
# 50%                              17264.0
# 75%                              17264.0
# max                              17264.0
#
#        To Account Received Transaction Count  \
# count                                  117.0
# mean                                   117.0
# std                                      0.0
# min                                    117.0
# 25%                                    117.0
# 50%                                    117.0
# 75%                                    117.0
# max                                    117.0
#
#        From Account Average Amount Paid  From Account Std Dev Amount Paid  \
# count                        117.000000                        117.000000
# mean                         645.110133                       1265.040502
# std                         2179.406745                       8100.420297
# min                           11.162095                          0.000000
# 25%                          125.660515                          0.000000
# 50%                          205.893585                         73.910955
# 75%                          511.738047                        172.346225
# max                        16727.008643                      62342.924437
#
#        From Account Average Amount Received  \
# count                              2.000000
# mean                           45776.805622
# std                                0.000000
# min                            45776.805622
# 25%                            45776.805622
# 50%                            45776.805622
# 75%                            45776.805622
# max                            45776.805622
#
#        From Account Std Dev Amount Received  To Account Average Amount Paid  \
# count                              2.000000                    1.170000e+02
# mean                           97000.360817                    2.718297e+05
# std                                0.000000                    5.845802e-10
# min                            97000.360817                    2.718297e+05
# 25%                            97000.360817                    2.718297e+05
# 50%                            97000.360817                    2.718297e+05
# 75%                            97000.360817                    2.718297e+05
# max                            97000.360817                    2.718297e+05
#
#        To Account Std Dev Amount Paid  To Account Average Amount Received  \
# count                    1.170000e+02                        1.170000e+02
# mean                     5.405056e+06                        1.133886e+03
# std                      1.215927e-08                        1.370110e-12
# min                      5.405056e+06                        1.133886e+03
# 25%                      5.405056e+06                        1.133886e+03
# 50%                      5.405056e+06                        1.133886e+03
# 75%                      5.405056e+06                        1.133886e+03
# max                      5.405056e+06                        1.133886e+03
#
#        To Account Std Dev Amount Received
# count                        1.170000e+02
# mean                         5.194969e+03
# std                          1.278769e-11
# min                          5.194969e+03
# 25%                          5.194969e+03
# 50%                          5.194969e+03
# 75%                          5.194969e+03
# max                          5.194969e+03

# %% [markdown]
# ### V7: Indication of Transaction was within the Bank

# %%
# New dummy variable "Within Bank" indicating if transaction occured within bank or not
df_v7 = df_v6.copy()
df_v7['Within Bank'] = (df_v7['From Bank'].astype(str) == df_v7['To Bank'].astype(str)).astype(int)
df_v7.head()
# Out:
#    Timestamp  From Bank From Account  To Bank To Account  Amount Received  \
# 0 2022-09-01        121    8123FB9B0      121  8123FB9B0        12.677957
# 1 2022-09-01      25170    8095AF7C0    25170  8095AF7C0      2977.670116
# 2 2022-09-01      25665    809A7D4B0    24779  809189BA0        74.103124
# 3 2022-09-01      32317    800D4E490    12004  800D4E750     13886.360391
# 4 2022-09-01       1024    800C8D9D0     1024  800C8D9D0        10.330801
#
#   Receiving Currency   Amount Paid Payment Currency Payment Format  \
# 0        Saudi Riyal     12.677957      Saudi Riyal   Reinvestment
# 1    Canadian Dollar   2977.670116  Canadian Dollar   Reinvestment
# 2    Canadian Dollar     74.103124  Canadian Dollar    Credit Card
# 3               Euro  13886.360391             Euro           Wire
# 4               Euro     10.330801             Euro   Reinvestment
#
#    Is Laundering  Digit Sum Amount Received  Digit Sum Amount Paid  \
# 0              0                         21                     21
# 1              0                         26                     26
# 2              0                         29                     29
# 3              0                         30                     30
# 4              0                         11                     11
#
#    Count Zeros Amount Received  Count Zeros Amount Paid  \
# 0                            4                        4
# 1                            4                        4
# 2                            4                        4
# 3                            5                        5
# 4                            5                        5
#
#    From Account Average Digit Sum Paid  From Account Average Count Zeros Paid  \
# 0                            24.000000                               4.333333
# 1                            19.666667                               4.666667
# 2                            17.700000                               4.700000
# 3                            30.000000                               5.000000
# 4                            19.333333                               4.766667
#
#    From Account Average Digit Sum Received  \
# 0                                26.071429
# 1                                18.500000
# 2                                22.000000
# 3                                      NaN
# 4                                19.250000
#
#    From Account Average Count Zeros Received  \
# 0                                   4.857143
# 1                                   4.000000
# 2                                   6.000000
# 3                                        NaN
# 4                                   4.500000
#
#    To Account Average Digit Sum Paid  To Account Average Count Zeros Paid  \
# 0                          24.000000                             4.333333
# 1                          19.666667                             4.666667
# 2                          27.017544                             4.438596
# 3                          26.000000                             4.888889
# 4                          19.333333                             4.766667
#
#    To Account Average Digit Sum Received  \
# 0                              26.071429
# 1                              18.500000
# 2                              18.463415
# 3                              25.500000
# 4                              19.250000
#
#    To Account Average Count Zeros Received  \
# 0                                 4.857143
# 1                                 4.000000
# 2                                 4.658537
# 3                                 4.500000
# 4                                 4.500000
#
#    From Account Average Zero Digit Ratio Paid  \
# 0                                    0.485185
# 1                                    0.500000
# 2                                    0.582143
# 3                                    0.454545
# 4                                    0.595648
#
#    From Account Average Zero Digit Ratio Received  \
# 0                                        0.488276
# 1                                        0.450000
# 2                                        0.600000
# 3                                             NaN
# 4                                        0.517361
#
#    To Account Average Zero Digit Ratio Paid  \
# 0                                  0.485185
# 1                                  0.500000
# 2                                  0.450642
# 3                                  0.485602
# 4                                  0.595648
#
#    To Account Average Zero Digit Ratio Received  From Account Amount Paid Min  \
# 0                                      0.488276                     12.677957
# 1                                      0.450000                   2977.670116
# 2                                      0.527153                     74.103124
# 3                                      0.458417                  13886.360391
# 4                                      0.517361                     10.330801
#
#    From Account Amount Paid Mean  From Account Amount Paid Median  \
# 0                      12.677957                        12.677957
# 1                    2977.670116                      2977.670116
# 2                      74.103124                        74.103124
# 3                   13886.360391                     13886.360391
# 4                      10.330801                        10.330801
#
#    From Account Amount Paid Max  From Account Amount Paid Sum  \
# 0                     12.677957                     12.677957
# 1                   2977.670116                   2977.670116
# 2                     74.103124                     74.103124
# 3                  13886.360391                  13886.360391
# 4                     10.330801                     10.330801
#
#    From Account Amount Paid Count  To Account Amount Received Min  \
# 0                             1.0                       12.677957
# 1                             1.0                     2977.670116
# 2                             1.0                       74.103124
# 3                             1.0                    13886.360391
# 4                             1.0                       10.330801
#
#    To Account Amount Received Mean  To Account Amount Received Median  \
# 0                        12.677957                          12.677957
# 1                      2977.670116                        2977.670116
# 2                        74.103124                          74.103124
# 3                     13886.360391                       13886.360391
# 4                        10.330801                          10.330801
#
#    To Account Amount Received Max  To Account Amount Received Sum  \
# 0                       12.677957                       12.677957
# 1                     2977.670116                     2977.670116
# 2                       74.103124                       74.103124
# 3                    13886.360391                    13886.360391
# 4                       10.330801                       10.330801
#
#    To Account Amount Received Count  From Account Average Amount Paid in ACH  \
# 0                               1.0                              2058.070954
# 1                               1.0                              2089.542390
# 2                               1.0                                      NaN
# 3                               1.0                                      NaN
# 4                               1.0                                      NaN
#
#    From Account Average Amount Paid in Bitcoin  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    From Account Average Amount Paid in Cash  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                               1876.450105
#
#    From Account Average Amount Paid in Cheque  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                  273.557031
#
#    From Account Average Amount Paid in Credit Card  \
# 0                                              NaN
# 1                                              NaN
# 2                                        63.796792
# 3                                              NaN
# 4                                         0.368601
#
#    From Account Average Amount Paid in Reinvestment  \
# 0                                        113.920650
# 1                                       1493.562942
# 2                                               NaN
# 3                                               NaN
# 4                                        264.361920
#
#    From Account Average Amount Paid in Wire  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                              13886.360391
# 4                                       NaN
#
#    To Account Average Amount Received in ACH  \
# 0                                        NaN
# 1                                        NaN
# 2                                 156.286217
# 3                                        NaN
# 4                                        NaN
#
#    To Account Average Amount Received in Bitcoin  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    To Account Average Amount Received in Cash  \
# 0                                         NaN
# 1                                         NaN
# 2                                  3659.92965
# 3                                         NaN
# 4                                         NaN
#
#    To Account Average Amount Received in Cheque  \
# 0                                  2.543906e+03
# 1                                           NaN
# 2                                  5.899356e+04
# 3                                  1.370731e+06
# 4                                  1.767892e+02
#
#    To Account Average Amount Received in Credit Card  \
# 0                                       27771.013808
# 1                                                NaN
# 2                                          52.150456
# 3                                                NaN
# 4                                                NaN
#
#    To Account Average Amount Received in Reinvestment  \
# 0                                         113.920650
# 1                                        1493.562942
# 2                                       34307.393825
# 3                                        2514.434374
# 4                                         264.361920
#
#    To Account Average Amount Received in Wire  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                13886.360391
# 4                                         NaN
#
#    From Account Paid Transaction Count  \
# 0                                  3.0
# 1                                  3.0
# 2                                 10.0
# 3                                  1.0
# 4                                 30.0
#
#    From Account Received Transaction Count  To Account Paid Transaction Count  \
# 0                                     14.0                                3.0
# 1                                      2.0                                3.0
# 2                                      1.0                               57.0
# 3                                      NaN                                9.0
# 4                                      4.0                               30.0
#
#    To Account Received Transaction Count  From Account Average Amount Paid  \
# 0                                   14.0                        761.970751
# 1                                    2.0                       1692.222758
# 2                                   41.0                         63.796792
# 3                                    4.0                      13886.360391
# 4                                    4.0                        583.208441
#
#    From Account Std Dev Amount Paid  From Account Average Amount Received  \
# 0                       1127.012371                           3998.701632
# 1                       1523.473423                           1493.562942
# 2                         85.324934                           2089.542390
# 3                               NaN                                   NaN
# 4                        761.247984                            220.575561
#
#    From Account Std Dev Amount Received  To Account Average Amount Paid  \
# 0                           7731.948289                      761.970751
# 1                           2098.844493                     1692.222758
# 2                                   NaN                     6466.005467
# 3                                   NaN                    32673.804392
# 4                            213.488954                      583.208441
#
#    To Account Std Dev Amount Paid  To Account Average Amount Received  \
# 0                     1127.012371                         3998.701632
# 1                     1523.473423                         1493.562942
# 2                    11491.606058                        13844.942578
# 3                    39634.853693                       347411.581432
# 4                      761.247984                          220.575561
#
#    To Account Std Dev Amount Received  Within Bank
# 0                         7731.948289            1
# 1                         2098.844493            1
# 2                        69680.093067            0
# 3                       682237.153093            0
# 4                          213.488954            1

# %% [markdown]
# ### V8: Extraction of "day", "hour" and "minute" from "Timestamp"

# %%
# Extract time components from variable "Timestamp"
df_v8 = df_v7.copy()
df_v8['Day'] = df_v8['Timestamp'].dt.day
df_v8['Hour'] = df_v8['Timestamp'].dt.hour
df_v8['Minute'] = df_v8['Timestamp'].dt.minute
df_v8.head()
# Out:
#    Timestamp  From Bank From Account  To Bank To Account  Amount Received  \
# 0 2022-09-01        121    8123FB9B0      121  8123FB9B0        12.677957
# 1 2022-09-01      25170    8095AF7C0    25170  8095AF7C0      2977.670116
# 2 2022-09-01      25665    809A7D4B0    24779  809189BA0        74.103124
# 3 2022-09-01      32317    800D4E490    12004  800D4E750     13886.360391
# 4 2022-09-01       1024    800C8D9D0     1024  800C8D9D0        10.330801
#
#   Receiving Currency   Amount Paid Payment Currency Payment Format  \
# 0        Saudi Riyal     12.677957      Saudi Riyal   Reinvestment
# 1    Canadian Dollar   2977.670116  Canadian Dollar   Reinvestment
# 2    Canadian Dollar     74.103124  Canadian Dollar    Credit Card
# 3               Euro  13886.360391             Euro           Wire
# 4               Euro     10.330801             Euro   Reinvestment
#
#    Is Laundering  Digit Sum Amount Received  Digit Sum Amount Paid  \
# 0              0                         21                     21
# 1              0                         26                     26
# 2              0                         29                     29
# 3              0                         30                     30
# 4              0                         11                     11
#
#    Count Zeros Amount Received  Count Zeros Amount Paid  \
# 0                            4                        4
# 1                            4                        4
# 2                            4                        4
# 3                            5                        5
# 4                            5                        5
#
#    From Account Average Digit Sum Paid  From Account Average Count Zeros Paid  \
# 0                            24.000000                               4.333333
# 1                            19.666667                               4.666667
# 2                            17.700000                               4.700000
# 3                            30.000000                               5.000000
# 4                            19.333333                               4.766667
#
#    From Account Average Digit Sum Received  \
# 0                                26.071429
# 1                                18.500000
# 2                                22.000000
# 3                                      NaN
# 4                                19.250000
#
#    From Account Average Count Zeros Received  \
# 0                                   4.857143
# 1                                   4.000000
# 2                                   6.000000
# 3                                        NaN
# 4                                   4.500000
#
#    To Account Average Digit Sum Paid  To Account Average Count Zeros Paid  \
# 0                          24.000000                             4.333333
# 1                          19.666667                             4.666667
# 2                          27.017544                             4.438596
# 3                          26.000000                             4.888889
# 4                          19.333333                             4.766667
#
#    To Account Average Digit Sum Received  \
# 0                              26.071429
# 1                              18.500000
# 2                              18.463415
# 3                              25.500000
# 4                              19.250000
#
#    To Account Average Count Zeros Received  \
# 0                                 4.857143
# 1                                 4.000000
# 2                                 4.658537
# 3                                 4.500000
# 4                                 4.500000
#
#    From Account Average Zero Digit Ratio Paid  \
# 0                                    0.485185
# 1                                    0.500000
# 2                                    0.582143
# 3                                    0.454545
# 4                                    0.595648
#
#    From Account Average Zero Digit Ratio Received  \
# 0                                        0.488276
# 1                                        0.450000
# 2                                        0.600000
# 3                                             NaN
# 4                                        0.517361
#
#    To Account Average Zero Digit Ratio Paid  \
# 0                                  0.485185
# 1                                  0.500000
# 2                                  0.450642
# 3                                  0.485602
# 4                                  0.595648
#
#    To Account Average Zero Digit Ratio Received  From Account Amount Paid Min  \
# 0                                      0.488276                     12.677957
# 1                                      0.450000                   2977.670116
# 2                                      0.527153                     74.103124
# 3                                      0.458417                  13886.360391
# 4                                      0.517361                     10.330801
#
#    From Account Amount Paid Mean  From Account Amount Paid Median  \
# 0                      12.677957                        12.677957
# 1                    2977.670116                      2977.670116
# 2                      74.103124                        74.103124
# 3                   13886.360391                     13886.360391
# 4                      10.330801                        10.330801
#
#    From Account Amount Paid Max  From Account Amount Paid Sum  \
# 0                     12.677957                     12.677957
# 1                   2977.670116                   2977.670116
# 2                     74.103124                     74.103124
# 3                  13886.360391                  13886.360391
# 4                     10.330801                     10.330801
#
#    From Account Amount Paid Count  To Account Amount Received Min  \
# 0                             1.0                       12.677957
# 1                             1.0                     2977.670116
# 2                             1.0                       74.103124
# 3                             1.0                    13886.360391
# 4                             1.0                       10.330801
#
#    To Account Amount Received Mean  To Account Amount Received Median  \
# 0                        12.677957                          12.677957
# 1                      2977.670116                        2977.670116
# 2                        74.103124                          74.103124
# 3                     13886.360391                       13886.360391
# 4                        10.330801                          10.330801
#
#    To Account Amount Received Max  To Account Amount Received Sum  \
# 0                       12.677957                       12.677957
# 1                     2977.670116                     2977.670116
# 2                       74.103124                       74.103124
# 3                    13886.360391                    13886.360391
# 4                       10.330801                       10.330801
#
#    To Account Amount Received Count  From Account Average Amount Paid in ACH  \
# 0                               1.0                              2058.070954
# 1                               1.0                              2089.542390
# 2                               1.0                                      NaN
# 3                               1.0                                      NaN
# 4                               1.0                                      NaN
#
#    From Account Average Amount Paid in Bitcoin  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    From Account Average Amount Paid in Cash  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                               1876.450105
#
#    From Account Average Amount Paid in Cheque  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                  273.557031
#
#    From Account Average Amount Paid in Credit Card  \
# 0                                              NaN
# 1                                              NaN
# 2                                        63.796792
# 3                                              NaN
# 4                                         0.368601
#
#    From Account Average Amount Paid in Reinvestment  \
# 0                                        113.920650
# 1                                       1493.562942
# 2                                               NaN
# 3                                               NaN
# 4                                        264.361920
#
#    From Account Average Amount Paid in Wire  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                              13886.360391
# 4                                       NaN
#
#    To Account Average Amount Received in ACH  \
# 0                                        NaN
# 1                                        NaN
# 2                                 156.286217
# 3                                        NaN
# 4                                        NaN
#
#    To Account Average Amount Received in Bitcoin  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    To Account Average Amount Received in Cash  \
# 0                                         NaN
# 1                                         NaN
# 2                                  3659.92965
# 3                                         NaN
# 4                                         NaN
#
#    To Account Average Amount Received in Cheque  \
# 0                                  2.543906e+03
# 1                                           NaN
# 2                                  5.899356e+04
# 3                                  1.370731e+06
# 4                                  1.767892e+02
#
#    To Account Average Amount Received in Credit Card  \
# 0                                       27771.013808
# 1                                                NaN
# 2                                          52.150456
# 3                                                NaN
# 4                                                NaN
#
#    To Account Average Amount Received in Reinvestment  \
# 0                                         113.920650
# 1                                        1493.562942
# 2                                       34307.393825
# 3                                        2514.434374
# 4                                         264.361920
#
#    To Account Average Amount Received in Wire  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                13886.360391
# 4                                         NaN
#
#    From Account Paid Transaction Count  \
# 0                                  3.0
# 1                                  3.0
# 2                                 10.0
# 3                                  1.0
# 4                                 30.0
#
#    From Account Received Transaction Count  To Account Paid Transaction Count  \
# 0                                     14.0                                3.0
# 1                                      2.0                                3.0
# 2                                      1.0                               57.0
# 3                                      NaN                                9.0
# 4                                      4.0                               30.0
#
#    To Account Received Transaction Count  From Account Average Amount Paid  \
# 0                                   14.0                        761.970751
# 1                                    2.0                       1692.222758
# 2                                   41.0                         63.796792
# 3                                    4.0                      13886.360391
# 4                                    4.0                        583.208441
#
#    From Account Std Dev Amount Paid  From Account Average Amount Received  \
# 0                       1127.012371                           3998.701632
# 1                       1523.473423                           1493.562942
# 2                         85.324934                           2089.542390
# 3                               NaN                                   NaN
# 4                        761.247984                            220.575561
#
#    From Account Std Dev Amount Received  To Account Average Amount Paid  \
# 0                           7731.948289                      761.970751
# 1                           2098.844493                     1692.222758
# 2                                   NaN                     6466.005467
# 3                                   NaN                    32673.804392
# 4                            213.488954                      583.208441
#
#    To Account Std Dev Amount Paid  To Account Average Amount Received  \
# 0                     1127.012371                         3998.701632
# 1                     1523.473423                         1493.562942
# 2                    11491.606058                        13844.942578
# 3                    39634.853693                       347411.581432
# 4                      761.247984                          220.575561
#
#    To Account Std Dev Amount Received  Within Bank  Day  Hour  Minute
# 0                         7731.948289            1    1     0       0
# 1                         2098.844493            1    1     0       0
# 2                        69680.093067            0    1     0       0
# 3                       682237.153093            0    1     0       0
# 4                          213.488954            1    1     0       0

# %% [markdown]
# ### Save File with all Variables

# %%
df_v8.to_csv('./df_all_var.csv', index=False)
